# %%
import networkx as nx
import plotly.graph_objects as go
import json

# JSON 파일 경로
json_file = 'shape_meas.json'  # JSON 파일의 경로를 넣어주세요.

print("JSON 파일 경로 설정 완료")

# JSON 파일 읽기
with open(json_file, 'r', encoding='utf-8') as f:
    data = json.load(f)

print("JSON 파일 읽기 완료")
print("데이터 내용: ", data)

# 그래프 생성
G = nx.DiGraph()

print("그래프 생성 완료")

# 노드 추가 함수 (재귀적으로 자식 노드들을 추가)
def add_nodes_from_json(data, parent=None):
    for node_id, node_info in data.items():
        if isinstance(node_info, dict):
            node_name = node_info.get("name", "Unnamed Node")
            print(f"노드 추가: {node_id} - {node_name}")
            G.add_node(node_id, label=node_name)  # 노드 추가
            if parent:
                G.add_edge(parent, node_id)  # 부모 노드와 자식 노드 연결
                print(f"엣지 추가: {parent} -> {node_id}")
            
            # 자식 노드들이 있으면 재귀적으로 추가
            children = node_info.get("children", {})
            add_nodes_from_json(children, parent=node_id)
        else:
            # 노드 정보가 문자열인 경우 (leaf 노드)
            print(f"노드 추가: {node_id} - {node_info}")
            G.add_node(node_id, label=node_info)  # 노드 추가
            if parent:
                G.add_edge(parent, node_id)  # 부모 노드와 자식 노드 연결
                print(f"엣지 추가: {parent} -> {node_id}")

# JSON 데이터를 그래프에 추가
add_nodes_from_json(data)

print("노드 및 엣지 추가 완료")

# 노드 레이블 설정
labels = nx.get_node_attributes(G, "label")
print("노드 레이블 설정 완료")

# 노드와 엣지 위치 설정
pos = nx.spring_layout(G, seed=42)

# 엣지 추가
edge_x = []
edge_y = []
for edge in G.edges():
    x0, y0 = pos[edge[0]]
    x1, y1 = pos[edge[1]]
    edge_x.append(x0)
    edge_x.append(x1)
    edge_x.append(None)
    edge_y.append(y0)
    edge_y.append(y1)
    edge_y.append(None)

edge_trace = go.Scatter(
    x=edge_x, y=edge_y,
    line=dict(width=1, color='#888'),
    hoverinfo='none',
    mode='lines'
)

# 노드 추가
node_x = []
node_y = []
for node in G.nodes():
    x, y = pos[node]
    node_x.append(x)
    node_y.append(y)

node_trace = go.Scatter(
    x=node_x, y=node_y,
    mode='markers+text',
    text=[labels[node] for node in G.nodes()],
    textposition="bottom center",
    marker=dict(
        size=10,
        color='lightgreen',
        line=dict(width=2)
    )
)

# 레이아웃 설정
fig = go.Figure(data=[edge_trace, node_trace],
                layout=go.Layout(
                    title='초등 수학 지식공간',
                    titlefont_size=16,
                    showlegend=False,
                    hovermode='closest',
                    margin=dict(b=20, l=5, r=5, t=40),
                    xaxis=dict(showgrid=False, zeroline=False),
                    yaxis=dict(showgrid=False, zeroline=False)
                ))

fig.show()
print("그래프 시각화 완료")
# Out:
# JSON 파일 경로 설정 완료
# JSON 파일 읽기 완료
# 데이터 내용:  {'03': {'name': '도형과 측정', 'children': {'03-01': {'name': '입체도형', 'children': {'03-01-02': {'name': '직육면체의 모양', 'children': {'03-01-02-01': '직육면체', '03-01-02-02': '직육면체의 구성요소와 성질', '03-01-02-03': '정육면체', '03-01-02-04': '정육면체의 구성요소와 성질', '03-01-02-05': '직육면체의 겨냥도', '03-01-02-06': '직육면체의 전개도', '03-01-02-07': '정육면체의 겨냥도', '03-01-02-08': '정육면체의 전개도', '03-01-02-09': '직육면체 겉넓이 구하기', '03-01-02-10': '정육면체 겉넓이 구하기', '03-01-02-11': '직육면체의 부피 구하기', '03-01-02-12': '정육면체의 부피 구하기'}}, '03-01-03': {'name': '원기둥의 모양', 'children': {'03-01-03-01': '원기둥', '03-01-03-02': '원뿔', '03-01-03-03': '원기둥의 구성요소와 성질', '03-01-03-04': '원뿔의 구성요소와 성질', '03-01-03-05': '원기둥 전개도'}}, '03-01-04': {'name': '구의 모양', 'children': {'03-01-04-01': '구 이해하기', '03-01-04-02': '구의 구성요소와 성질'}}, '03-01-05': {'name': '여러 모양으로 쌓기', 'children': {'03-01-05-01': '모양에 대해 위치나 방향을 이용하여 말하기', '03-01-05-02': '입체도형의 쌓기나무 개수 구하기', '03-01-05-03': '입체도형의 위. 앞. 옆에서 본 모양 표현하기', '03-01-05-04': '입체도형의 모양 추론하기'}}, '03-01-07': {'name': '각기둥', 'children': {'03-01-07-01': '각기둥 이해하기', '03-01-07-02': '각기둥의 구성요소와 성질'}}, '03-01-08': {'name': '각뿔', 'children': {'03-01-08-01': '각뿔 이해하기', '03-01-08-02': '각뿔의 구성요소와 성질'}}}}, '03-02': {'name': '평면도형', 'children': {'03-02-01': '생활 속 여러 물건의 모양', '03-02-02': {'name': '삼각형', 'children': {'03-02-02-01': '여러 가지 삼각형 분류하기', '03-02-02-02': '이등변삼각형', '03-02-02-03': '정삼각형', '03-02-02-04': '직각삼각형', '03-02-02-05': '예각삼각형', '03-02-02-06': '둔각삼각형'}}, '03-02-03': {'name': '사각형', 'children': {'03-02-03-01': '여러 가지 사각형 분류하기', '03-02-03-02': '직사각형', '03-02-03-03': '정사각형', '03-02-03-04': '사다리꼴', '03-02-03-05': '평행사변형', '03-02-03-06': '마름모'}}, '03-02-04': {'name': '원', 'children': {'03-02-04-01': '원의 중심', '03-02-04-02': '원의 반지름', '03-02-04-03': '원의 지름', '03-02-04-04': '원의 성질', '03-02-04-05': '컴퍼스를 이용해 원 그리기', '03-02-04-06': '원주와 지름 측정하기', '03-02-04-07': '원주율 이해하기', '03-02-04-08': '원주 구하기', '03-02-04-09': '원의 넓이 구하기'}}, '03-02-05': '직선, 선분, 반직선', '03-02-06': {'name': '각', 'children': {'03-02-06-01': '직각', '03-02-06-02': '예각', '03-02-06-03': '둔각', '03-02-06-04': '직선의 수직관계', '03-02-06-05': '직선의 평행관계', '03-02-06-06': '각의 단위 이해하기', '03-02-06-07': '각의 크기 측정하기', '03-02-06-08': '각의 크기 어림하기', '03-02-06-09': '삼각형의 내각의 크기의 합 추론하기', '03-02-06-10': '사각형의 내각의 크기의 합 추론하기'}}, '03-02-07': {'name': '평면도형의 이동', 'children': {'03-02-07-01': '도형 밀기, 뒤집기, 돌리기', '03-02-07-02': '평면에서의 점의 이동', '03-02-07-03': '도형의 합동 이해하기', '03-02-07-04': '합동인 도형의 성질', '03-02-07-05': '선대칭도형', '03-02-07-06': '점대칭도형'}}, '03-02-08': {'name': '다각형과 정다각형', 'children': {'03-02-08-01': '다각형', '03-02-08-02': '정다각형', '03-02-08-03': '주어진 도형으로 여러 가지 모양 만들거나 채우기', '03-02-08-04': '평면도형의 둘레', '03-02-08-05': '직사각형의 넓이', '03-02-08-06': '정사각형의 넓이', '03-02-08-07': '사다리꼴의 넓이', '03-02-08-08': '평행사변형의 넓이', '03-02-08-09': '마름모의 넓이'}}}}, '03-03': {'name': '양의 비교', 'children': {'03-03-01': {'name': '길이', 'children': {'03-03-01-01': '길이 단위 이해하기', '03-03-01-02': '길이 측정하기', '03-03-01-03': '1m와 1cm의 관계 이해하기', '03-03-01-04': '물건의 길이 어림하기', '03-03-01-05': '길이의 덧셈', '03-03-01-06': '길이의 뺄셈', '03-03-01-07': '1mm', '03-03-01-08': '1km', '03-03-01-09': '길이 측정하기', '03-03-01-10': '길이 어림하기', '03-03-01-11': '길이의 관계 이해하기'}}, '03-03-02': {'name': '들이', 'children': {'03-03-02-01': '들이 단위 이해하기', '03-03-02-02': '들이 측정하기', '03-03-02-03': '들이 어림하기', '03-03-02-04': '1L와 1mL의 관계 이해하기', '03-03-02-05': '들이의 덧셈', '03-03-02-06': '들이의 뺄셈'}}, '03-03-03': {'name': '무게', 'children': {'03-03-03-01': '무게 단위 이해하기', '03-03-03-02': '무게 측정하기', '03-03-03-03': '무게 어림하기', '03-03-03-04': '1kg와 1g의 관계 이해하기', '03-03-03-05': '1kg와 1t의 관계 이해하기', '03-03-03-06': '무게의 덧셈', '03-03-03-07': '무게의 뺄셈'}}, '03-03-04': {'name': '넓이', 'children': {'03-03-04-01': '넓이 단위 이해하기'}}, '03-03-06': {'name': '부피', 'children': {'03-03-06-01': '부피 단위 이해하기'}}}}, '03-04': {'name': '시각과 시간', 'children': {'03-04-01': {'name': '시각', 'children': {'03-04-01-01': '시계 읽기', '03-04-01-02': '초 단위까지 시각 읽기'}}, '03-04-02': {'name': '시간', 'children': {'03-04-02-01': '시간과 분의 관계 이해하기', '03-04-02-02': '1분, 1시간, 1일, 1주일, 1개월, 1 ...
# 그래프 생성 완료
# 노드 추가: 03 - 도형과 측정
# 노드 추가: 03-01 - 입체도형
# 엣지 추가: 03 -> 03-01
# 노드 추가: 03-01-02 - 직육면체의 모양
# 엣지 추가: 03-01 -> 03-01-02
# 노드 추가: 03-01-02-01 - 직육면체
# 엣지 추가: 03-01-02 -> 03-01-02-01
# 노드 추가: 03-01-02-02 - 직육면체의 구성요소와 성질
# 엣지 추가: 03-01-02 -> 03-01-02-02
# 노드 추가: 03-01-02-03 - 정육면체
# 엣지 추가: 03-01-02 -> 03-01-02-03
# 노드 추가: 03-01-02-04 - 정육면체의 구성요소와 성질
# 엣지 추가: 03-01-02 -> 03-01-02-04
# 노드 추가: 03-01-02-05 - 직육면체의 겨냥도
# 엣지 추가: 03-01-02 -> 03-01-02-05
# 노드 추가: 03-01-02-06 - 직육면체의 전개도
# 엣지 추가: 03-01-02 -> 03-01-02-06
# 노드 추가: 03-01-02-07 - 정육면체의 겨냥도
# 엣지 추가: 03-01-02 -> 03-01-02-07
# 노드 추가: 03-01-02-08 - 정육면체의 전개도
# 엣지 추가: 03-01-02 -> 03-01-02-08
# 노드 추가: 03-01-02-09 - 직육면체 겉넓이 구하기
# 엣지 추가: 03-01-02 -> 03-01-02-09
# 노드 추가: 03-01-02-10 - 정육면체 겉넓이 구하기
# 엣지 추가: 03-01-02 -> 03-01-02-10
# 노드 추가: 03-01-02-11 - 직육면체의 부피 구하기
# 엣지 추가: 03-01-02 -> 03-01-02-11
# 노드 추가: 03-01-02-12 - 정육면체의 부피 구하기
# 엣지 추가: 03-01-02 -> 03-01-02-12
# 노드 추가: 03-01-03 - 원기둥의 모양
# 엣지 추가: 03-01 -> 03-01-03
# 노드 추가: 03-01-03-01 - 원기둥
# 엣지 추가: 03-01-03 -> 03-01-03-01
# 노드 추가: 03-01-03-02 - 원뿔
# 엣지 추가: 03-01-03 -> 03-01-03-02
# 노드 추가: 03-01-03-03 - 원기둥의 구성요소와 성질
# 엣지 추가: 03-01-03 -> 03-01-03-03
# 노드 추가: 03-01-03-04 - 원뿔의 구성요소와 성질
# 엣지 추가: 03-01-03 -> 03-01-03-04
# 노드 추가: 03-01-03-05 - 원기둥 전개도
# 엣지 추가: 03-01-03 -> 03-01-03-05
# 노드 추가: 03-01-04 - 구의 모양
# 엣지 추가: 03-01 -> 03-01-04
# 노드 추가: 03-01-04-01 - 구 이해하기
# 엣지 추가: 03-01-04 -> 03-01-04-01
# 노드 추가: 03-01-04-02 - 구의 구성요소와 성질
# 엣지 추가: 03-01-04 -> 03-01-04-02
# 노드 추가: 03-01-05 - 여러 모양으로 쌓기
# 엣지 추가: 03-01 -> 03-01-05
# 노드 추가: 03-01-05-01 - 모양에 대해 위치나 방향을 이용하여 말하기
# 엣지 추가: 03-01-05 -> 03-01-05-01
# 노드 추가: 03-01-05-02 - 입체도형의 쌓기나무 개수 구하기
# 엣지 추가: 03-01-05 -> 03-01-05-02
# 노드 추가: 03-01-05-03 - 입체도형의 위. 앞. 옆에서 본 모양 표현하기
# 엣지 추가: 03-01-05 -> 03-01-05-03
# 노드 추가: 03-01-05-04 - 입체도형의 모양 추론하기
# 엣지 추가: 03-01-05 -> 03-01-05-04
# 노드 추가: 03-01-07 - 각기둥
# 엣지 추가: 03-01 -> 03-01-07
# 노드 추가: 03-01-07-01 - 각기둥 이해하기
# 엣지 추가: 03-01-07 -> 03-01-07-01
# 노드 추가: 03-01-07-02 - 각기둥의 구성요소와 성질
# 엣지 추가: 03-01-07 -> 03-01-07-02
# 노드 추가: 03-01-08 - 각뿔
# 엣지 추가: 03-01 -> 03-01-08
# 노드 추가: 03-01-08-01 - 각뿔 이해하기
# 엣지 추가: 03-01-08 -> 03-01-08-01
# 노드 추가: 03-01-08-02 - 각뿔의 구성요소와 성질
# 엣지 추가: 03-01-08 -> 03-01-08-02
# 노드 추가: 03-02 - 평면도형
# 엣지 추가: 03 -> 03-02
# 노드 추가: 03-02-01 - 생활 속 여러 물건의 모양
# 엣지 추가: 03-02 -> 03-02-01
# 노드 추가: 03-02-02 - 삼각형
# 엣지 추가: 03-02 -> 03-02-02
# 노드 추가: 03-02-02-01 - 여러 가지 삼각형 분류하기
# 엣지 추가: 03-02-02 -> 03-02-02-01
# 노드 추가: 03-02-02-02 - 이등변삼각형
# 엣지 추가: 03-02-02 -> 03-02-02-02
# 노드 추가: 03-02-02-03 - 정삼각형
# 엣지 추가: 03-02-02 -> 03-02-02-03
# 노드 추가: 03-02-02-04 - 직각삼각형
# 엣지 추가: 03-02-02 -> 03-02-02-04
# 노드 추가: 03-02-02-05 - 예각삼각형
# 엣지 추가: 03-02-02 -> 03-02-02-05
# 노드 추가: 03-02-02-06 - 둔각삼각형
# 엣지 추가: 03-02-02 -> 03-02-02-06
# 노드 추가: 03-02-03 - 사각형
# 엣지 추가: 03-02 -> 03-02-03
# 노드 추가: 03-02-03-01 - 여러 가지 사각형 분류하기
# 엣지 추가: 03-02-03 -> 03-02-03-01
# 노드 추가: 03-02-03-02 - 직사각형
# 엣지 추가: 03-02-03 -> 03-02-03-02
# 노드 추가: 03-02-03-03 - 정사각형
# 엣지 추가: 03-02-03 -> 03-02-03-03
# 노드 추가: 03-02-03-04 - 사다리꼴
# 엣지 추가: 03-02-03 -> 03-02-03-04
# 노드 추가: 03-02-03-05 - 평행사변형
# 엣지 추가: 03-02-03 -> 03-02-03-05
# 노드 추가: 03-02-03-06 - 마름모
# 엣지 추가: 03-02-03 -> 03-02-03-06
# 노드 추가: 03-02-04 - 원
# 엣지 추가: 03-02 -> 03-02-04
# 노드 추가: 03-02-04-01 - 원의 중심
# 엣지 추가: 03-02-04 -> 03-02-04-01
# 노드 추가: 03-02-04-02 - 원의 반지름
# 엣지 추가: 03-02-04 -> 03-02-04-02
# 노드 추가: 03-02-04-03 - 원의 지름
# 엣지 추가: 03-02-04 -> 03-02-04-03
# 노드 추가: 03-02-04-04 - 원의 성질
# 엣지 추가: 03-02-04 -> 03-02-04-04
# 노드 추가: 03-02-04-05 - 컴퍼스를 이용해 원 그리기
# 엣지 추가: 03-02-04 -> 03-02-04-05
# 노드 추가: 03-02-04-06 - 원주와 지름 측정하기
# 엣지 추가: 03-02-04 -> 03-02-04-06
# 노드 추가: 03-02-04-07 - 원주율 이해하기
# 엣지 추가: 03-02-04 -> 03-02-04-07
# 노드 추가: 03-02-04-08 - 원주 구하기
# 엣지 추가: 03-02-04 -> 03-02-04-08
# 노드 추가: 03-02-04-09 - 원의 넓이 구하기
# 엣지 추가: 03-02-04 -> 03-02-04-09
# 노드 추가: 03-02-05 - 직선, 선분, 반직선
# 엣지 추가: 03-02 -> 03-02-05
# 노드 추가: 03-02-06 - 각
# 엣지 추가: 03-02 -> 03-02-06
# 노드 추가: 03-02-06-01 - 직각
# 엣지 추가: 03-02-06 -> 03-02-06-01
# 노드 추가: 03-02-06-02 - 예각
# 엣지 추가: 03-02-06 -> 03-02-06-02
# 노드 추가: 03-02-06-03 - 둔각
# 엣지 추가: 03-02-06 -> 03-02-06-03
# 노드 추가: 03-02-06-04 - 직선의 수직관계
# 엣지 추가: 03-02-06 -> 03-02-06-04
# 노드 추가: 03-02-06-05 - 직선의 평행관계
# 엣지 추가: 03-02-06 -> 03-02-06-05
# 노드 추가: 03-02-06-06 - 각의 단위 이해하기
# 엣지 추가: 03-02-06 -> 03-02-06-06
# 노드 추가: 03-02-06-07 - 각의 크기 측정하기
# 엣지 추가: 03-02-06 -> 03-02-06-07
# 노드 추가: 03-02-06-08 - 각의 크기 어림하기
# 엣지 추가: 03-02-06 -> 03-02-06-08
# 노드 추가: 03-02-06-09 - 삼각형의 내각의 크기의 합 추론하기
# 엣지 추가: 03-02-06 -> 03-02-06-09
# 노드 추가: 03-02-06-10 - 사각형의 내각의 크기의 합 추론하기
# 엣지 추가: 03-02-06 -> 03-02-06-10
# 노드 추가: 03-02-07 - 평면도형의 이동
# 엣지 추가: 03-02 -> 03-02-07
# 노드 추가: 03-02-07-01 - 도형 밀기, 뒤집기, 돌리기
# 엣지 추가: 03-02-07 -> 03-02-07-01
# 노드 추가: 03-02-07-02 - 평면에서의 점의 이동
# 엣지 추가: 03-02-07 -> 03-02-07-02
# 노드 추가: 03-02-07-03 - 도형의 합동 이해하기
# 엣지 추가: 03-02-07 -> 03-02-07-03
# 노드 추가: 03-02-07-04 - 합동인 도형의 성질
# 엣지 추가: 03-02-07 -> 03-02-07-04
# 노드 추가: 03-02-07-05 - 선대칭도형
# 엣지 추가: 03-02-07 -> 03-02-07-05
# 노드 추가: 03-02-07-06 - 점대칭도형
# 엣지 추가: 03-02-07 -> 03-02-07-06
# 노드 추가: 03-02-08 - 다각형과 정다각형
# 엣지 추가: 03-02 -> 03-02-08
# 노드 추가: 03-02-08-01 - 다각형
# 엣지 추가: 03-02-08 -> 03-02-08-01
# 노드 추가: 03-02-08-02 - 정다각형
# 엣지 추가: 03-02-08 -> 03-02-08-02
# 노드 추가: 03-02-08-03 - 주어진 도형으로 여러 가지 모양 만들거나 채우기
# 엣지 추가: 03-02-08 -> 03-02-08-03
# 노드 추가: 03-02-08-04 - 평면도형의 둘레
# 엣지 추가: 03-02-08 -> 03-02-08-04
# 노드 추가: 03-02-08-05 - 직사각형의 넓이
# 엣지 추가: 03-02-08 -> 03-02-08-05
# 노드 추가: 03-02-08-06 - 정사각형의 넓이
# 엣지 추가: 03-02-08 -> 03-02-08-06
# 노드 추가: 03-02-08-07 - 사다리꼴의 넓이
# 엣지 추가: 03-02-08 -> 03-02-08-07
# 노드 추가: 03-02-08-08 - 평행사변형의 넓이
# 엣지 추가: 03-02-08 -> 03-02-08-08
# 노드 추가: 03-02-08-09 - 마름모의 넓이
# 엣지 추가: 03-02-08 -> 03-02-08-09
# 노드 추가: 03-03 - 양의 비교
# 엣지 추가: 03 -> 03-03
# 노드 추가: 03-03-01 - 길이
# 엣지 추가: 03-03 -> 03-03-01
# 노드 추가: 03-03-01-01 - 길이 단위 이해하기
# 엣지 추가: 03-03-01 -> 03-03-01-01
# 노드 추가: 03-03-01-02 - 길이 측정하기
# 엣지 추가: 03-03-01 -> 03-03-01-02
# 노드 추가: 03-03-01-03 - 1m와 1cm의 관계 이해하기
# 엣지 추가: 03-03-01 -> 03-03-01-03
# 노드 추가: 03-03-01-04 - 물건의 길이 어림하기
# 엣지 추가: 03-03-01 -> 03-03-01-04
# 노드 추가: 03-03-01-05 - 길이의 덧셈
# 엣지 추가: 03-03-01 -> 03-03-01-05
# 노드 추가: 03-03-01-06 - 길이의 뺄셈
# 엣지 추가: 03-03-01 -> 03-03-01-06
# 노드 추가: 03-03-01-07 - 1mm
# 엣지 추가: 03-03-01 -> 03-03-01-07
# 노드 추가: 03-03-01-08 - 1km
# 엣지 추가: 03-03-01 -> 03-03-01-08
# 노드 추가: 03-03-01-09 - 길이 측정하기
# 엣지 추가: 03-03-01 -> 03-03-01-09
# 노드 추가: 03-03-01-10 - 길이 어림하기
# 엣지 추가: 03-03-01 -> 03-03-01-10
# 노드 추가: 03-03-01-11 - 길이의 관계 이해하기
# 엣지 추가: 03-03-01 -> 03-03-01-11
# 노드 추가: 03-03-02 - 들이
# 엣지 추가: 03-03 -> 03-03-02
# 노드 추가: 03-03-02-01 - 들이 단위 이해하기
# 엣지 추가: 03-03-02 -> 03-03-02-01
# 노드 추가: 03-03-02-02 - 들이 측정하기
# 엣지 추가: 03-03-02 -> 03-03-02-02
# 노드 추가: 03-03-02-03 - 들이 어림하기
# 엣지 추가: 03-03-02 -> 03-03-02-03
# 노드 추가: 03-03-02-04 - 1L와 1mL의 관계 이해하기
# 엣지 추가: 03-03-02 -> 03-03-02-04
# 노드 추가: 03-03-02-05 - 들이의 덧셈
# 엣지 추가: 03-03-02 -> 03-03-02-05
# 노드 추가: 03-03-02-06 - 들이의 뺄셈
# 엣지 추가: 03-03-02 -> 03-03-02-06
# 노드 추가: 03-03-03 - 무게
# 엣지 추가: 03-03 -> 03-03-03
# 노드 추가: 03-03-03-01 - 무게 단위 이해하기
# 엣지 추가: 03-03-03 -> 03-03-03-01
# 노드 추가: 03-03-03-02 - 무게 측정하기
# 엣지 추가: 03-03-03 -> 03-03-03-02
# 노드 추가: 03-03-03-03 - 무게 어림하기
# 엣지 추가: 03-03-03 -> 03-03-03-03
# 노드 추가: 03-03-03-04 - 1kg와 1g의 관계 이해하기
# 엣지 추가: 03-03-03 -> 03-03-03-04
# 노드 추가: 03-03-03-05 - 1kg와 1t의 관계 이해하기
# 엣지 추가: 03-03-03 -> 03-03-03-05
# 노드 추가: 03-03-03-06 - 무게의 덧셈
# 엣지 추가: 03-03-03 -> 03-03-03-06
# 노드 추가: 03-03-03-07 - 무게의 뺄셈
# 엣지 추가: 03-03-03 -> 03-03-03-07
# 노드 추가: 03-03-04 - 넓이
# 엣지 추가: 03-03 -> 03-03-04
# 노드 추가: 03-03-04-01 - 넓이 단위 이해하기
# 엣지 추가: 03-03-04 -> 03-03-04-01
# 노드 추가: 03-03-06 - 부피
# 엣지 추가: 03-03 -> 03-03-06
# 노드 추가: 03-03-06-01 - 부피 단위 이해하기
# 엣지 추가: 03-03-06 -> 03-03-06-01
# 노드 추가: 03-04 - 시각과 시간
# 엣지 추가: 03 -> 03-04
# 노드 추가: 03-04-01 - 시각
# 엣지 추가: 03-04 -> 03-04-01
# 노드 추가: 03-04-01-01 - 시계 읽기
# 엣지 추가: 03-04-01 -> 03-04-01-01
# 노드 추가: 03-04-01-02 - 초 단위까지 시각 읽기
# 엣지 추가: 03-04-01 -> 03-04-01-02
# 노드 추가: 03-04-02 - 시간
# 엣지 추가: 03-04 -> 03-04-02
# 노드 추가: 03-04-02-01 - 시간과 분의 관계 이해하기
# 엣지 추가: 03-04-02 -> 03-04-02-01
# 노드 추가: 03-04-02-02 - 1분, 1시간, 1일, 1주일, 1개월, 1년 사이의 관계 이해하기
# 엣지 추가: 03-04-02 -> 03-04-02-02
# 노드 추가: 03-04-02-03 - 1분과 1초의 관계
# 엣지 추가: 03-04-02 -> 03-04-02-03
# 노드 추가: 03-04-02-04 - 시간의 덧셈
# 엣지 추가: 03-04-02 -> 03-04-02-04
# 노드 추가: 03-04-02-05 - 시간의 뺄셈
# 엣지 추가: 03-04-02 -> 03-04-02-05
# 노드 및 엣지 추가 완료
# 노드 레이블 설정 완료
# 그래프 시각화 완료

# %%
import networkx as nx
import plotly.graph_objects as go
import json
from konlpy.tag import Okt

# 형태소 분석기 초기화
okt = Okt()

# JSON 파일 경로
json_file = 'shape_meas.json'  # JSON 파일의 경로를 넣어주세요.

print("JSON 파일 경로 설정 완료")

# JSON 파일 읽기
with open(json_file, 'r', encoding='utf-8') as f:
    data = json.load(f)

print("JSON 파일 읽기 완료")
print("데이터 내용: ", data)

# 그래프 생성
G = nx.DiGraph()

print("그래프 생성 완료")

# 노드 추가 함수 (재귀적으로 자식 노드들을 추가)
def add_nodes_from_json(data, parent=None):
    for node_id, node_info in data.items():
        if isinstance(node_info, dict):
            node_name = node_info.get("name", "Unnamed Node")
            print(f"노드 추가: {node_id} - {node_name}")
            G.add_node(node_id, label=node_name)  # 노드 추가
            if parent:
                G.add_edge(parent, node_id)  # 부모 노드와 자식 노드 연결
                print(f"엣지 추가: {parent} -> {node_id}")
            
            # 자식 노드들이 있으면 재귀적으로 추가
            children = node_info.get("children", {})
            add_nodes_from_json(children, parent=node_id)
        else:
            # 노드 정보가 문자열인 경우 (leaf 노드)
            print(f"노드 추가: {node_id} - {node_info}")
            G.add_node(node_id, label=node_info)  # 노드 추가
            if parent:
                G.add_edge(parent, node_id)  # 부모 노드와 자식 노드 연결
                print(f"엣지 추가: {parent} -> {node_id}")

# JSON 데이터를 그래프에 추가
add_nodes_from_json(data)

print("노드 및 엣지 추가 완료")

# 노드 레이블 설정
labels = nx.get_node_attributes(G, "label")
print("노드 레이블 설정 완료")

# 형태소 분석을 통한 비슷한 키워드 연결
def connect_similar_keywords(G, labels):
    nodes = list(G.nodes())
    for i, node1 in enumerate(nodes):
        for node2 in nodes[i+1:]:
            label1 = labels[node1]
            label2 = labels[node2]
            
            # 형태소 분석 후 명사 추출
            nouns1 = set(okt.nouns(label1))
            nouns2 = set(okt.nouns(label2))
            
            # 공통 명사가 있는지 확인
            if nouns1 & nouns2:
                G.add_edge(node1, node2)
                print(f"비슷한 키워드로 엣지 추가: {node1} -> {node2}")

# 비슷한 키워드로 노드 연결
connect_similar_keywords(G, labels)

# 노드와 엣지 위치 설정
pos = nx.spring_layout(G, seed=42)

# 엣지 추가
edge_x = []
edge_y = []
for edge in G.edges():
    x0, y0 = pos[edge[0]]
    x1, y1 = pos[edge[1]]
    edge_x.append(x0)
    edge_x.append(x1)
    edge_x.append(None)
    edge_y.append(y0)
    edge_y.append(y1)
    edge_y.append(None)

edge_trace = go.Scatter(
    x=edge_x, y=edge_y,
    line=dict(width=1, color='#888'),
    hoverinfo='none',
    mode='lines'
)

# 노드 추가
node_x = []
node_y = []
for node in G.nodes():
    x, y = pos[node]
    node_x.append(x)
    node_y.append(y)

node_trace = go.Scatter(
    x=node_x, y=node_y,
    mode='markers+text',
    text=[labels[node] for node in G.nodes()],
    textposition="bottom center",
    marker=dict(
        size=10,
        color='lightgreen',
        line=dict(width=2)
    )
)

# 레이아웃 설정
fig = go.Figure(data=[edge_trace, node_trace],
                layout=go.Layout(
                    title='초등 수학 지식공간',
                    titlefont_size=16,
                    showlegend=False,
                    hovermode='closest',
                    margin=dict(b=20, l=5, r=5, t=40),
                    xaxis=dict(showgrid=False, zeroline=False),
                    yaxis=dict(showgrid=False, zeroline=False)
                ))

fig.show()
print("그래프 시각화 완료")
# Out:
# JSON 파일 경로 설정 완료
# JSON 파일 읽기 완료
# 데이터 내용:  {'03': {'name': '도형과 측정', 'children': {'03-01': {'name': '입체도형', 'children': {'03-01-02': {'name': '직육면체의 모양', 'children': {'03-01-02-01': '직육면체', '03-01-02-02': '직육면체의 구성요소와 성질', '03-01-02-03': '정육면체', '03-01-02-04': '정육면체의 구성요소와 성질', '03-01-02-05': '직육면체의 겨냥도', '03-01-02-06': '직육면체의 전개도', '03-01-02-07': '정육면체의 겨냥도', '03-01-02-08': '정육면체의 전개도', '03-01-02-09': '직육면체 겉넓이 구하기', '03-01-02-10': '정육면체 겉넓이 구하기', '03-01-02-11': '직육면체의 부피 구하기', '03-01-02-12': '정육면체의 부피 구하기'}}, '03-01-03': {'name': '원기둥의 모양', 'children': {'03-01-03-01': '원기둥', '03-01-03-02': '원뿔', '03-01-03-03': '원기둥의 구성요소와 성질', '03-01-03-04': '원뿔의 구성요소와 성질', '03-01-03-05': '원기둥 전개도'}}, '03-01-04': {'name': '구의 모양', 'children': {'03-01-04-01': '구 이해하기', '03-01-04-02': '구의 구성요소와 성질'}}, '03-01-05': {'name': '여러 모양으로 쌓기', 'children': {'03-01-05-01': '모양에 대해 위치나 방향을 이용하여 말하기', '03-01-05-02': '입체도형의 쌓기나무 개수 구하기', '03-01-05-03': '입체도형의 위. 앞. 옆에서 본 모양 표현하기', '03-01-05-04': '입체도형의 모양 추론하기'}}, '03-01-07': {'name': '각기둥', 'children': {'03-01-07-01': '각기둥 이해하기', '03-01-07-02': '각기둥의 구성요소와 성질'}}, '03-01-08': {'name': '각뿔', 'children': {'03-01-08-01': '각뿔 이해하기', '03-01-08-02': '각뿔의 구성요소와 성질'}}}}, '03-02': {'name': '평면도형', 'children': {'03-02-01': '생활 속 여러 물건의 모양', '03-02-02': {'name': '삼각형', 'children': {'03-02-02-01': '여러 가지 삼각형 분류하기', '03-02-02-02': '이등변삼각형', '03-02-02-03': '정삼각형', '03-02-02-04': '직각삼각형', '03-02-02-05': '예각삼각형', '03-02-02-06': '둔각삼각형'}}, '03-02-03': {'name': '사각형', 'children': {'03-02-03-01': '여러 가지 사각형 분류하기', '03-02-03-02': '직사각형', '03-02-03-03': '정사각형', '03-02-03-04': '사다리꼴', '03-02-03-05': '평행사변형', '03-02-03-06': '마름모'}}, '03-02-04': {'name': '원', 'children': {'03-02-04-01': '원의 중심', '03-02-04-02': '원의 반지름', '03-02-04-03': '원의 지름', '03-02-04-04': '원의 성질', '03-02-04-05': '컴퍼스를 이용해 원 그리기', '03-02-04-06': '원주와 지름 측정하기', '03-02-04-07': '원주율 이해하기', '03-02-04-08': '원주 구하기', '03-02-04-09': '원의 넓이 구하기'}}, '03-02-05': '직선, 선분, 반직선', '03-02-06': {'name': '각', 'children': {'03-02-06-01': '직각', '03-02-06-02': '예각', '03-02-06-03': '둔각', '03-02-06-04': '직선의 수직관계', '03-02-06-05': '직선의 평행관계', '03-02-06-06': '각의 단위 이해하기', '03-02-06-07': '각의 크기 측정하기', '03-02-06-08': '각의 크기 어림하기', '03-02-06-09': '삼각형의 내각의 크기의 합 추론하기', '03-02-06-10': '사각형의 내각의 크기의 합 추론하기'}}, '03-02-07': {'name': '평면도형의 이동', 'children': {'03-02-07-01': '도형 밀기, 뒤집기, 돌리기', '03-02-07-02': '평면에서의 점의 이동', '03-02-07-03': '도형의 합동 이해하기', '03-02-07-04': '합동인 도형의 성질', '03-02-07-05': '선대칭도형', '03-02-07-06': '점대칭도형'}}, '03-02-08': {'name': '다각형과 정다각형', 'children': {'03-02-08-01': '다각형', '03-02-08-02': '정다각형', '03-02-08-03': '주어진 도형으로 여러 가지 모양 만들거나 채우기', '03-02-08-04': '평면도형의 둘레', '03-02-08-05': '직사각형의 넓이', '03-02-08-06': '정사각형의 넓이', '03-02-08-07': '사다리꼴의 넓이', '03-02-08-08': '평행사변형의 넓이', '03-02-08-09': '마름모의 넓이'}}}}, '03-03': {'name': '양의 비교', 'children': {'03-03-01': {'name': '길이', 'children': {'03-03-01-01': '길이 단위 이해하기', '03-03-01-02': '길이 측정하기', '03-03-01-03': '1m와 1cm의 관계 이해하기', '03-03-01-04': '물건의 길이 어림하기', '03-03-01-05': '길이의 덧셈', '03-03-01-06': '길이의 뺄셈', '03-03-01-07': '1mm', '03-03-01-08': '1km', '03-03-01-09': '길이 측정하기', '03-03-01-10': '길이 어림하기', '03-03-01-11': '길이의 관계 이해하기'}}, '03-03-02': {'name': '들이', 'children': {'03-03-02-01': '들이 단위 이해하기', '03-03-02-02': '들이 측정하기', '03-03-02-03': '들이 어림하기', '03-03-02-04': '1L와 1mL의 관계 이해하기', '03-03-02-05': '들이의 덧셈', '03-03-02-06': '들이의 뺄셈'}}, '03-03-03': {'name': '무게', 'children': {'03-03-03-01': '무게 단위 이해하기', '03-03-03-02': '무게 측정하기', '03-03-03-03': '무게 어림하기', '03-03-03-04': '1kg와 1g의 관계 이해하기', '03-03-03-05': '1kg와 1t의 관계 이해하기', '03-03-03-06': '무게의 덧셈', '03-03-03-07': '무게의 뺄셈'}}, '03-03-04': {'name': '넓이', 'children': {'03-03-04-01': '넓이 단위 이해하기'}}, '03-03-06': {'name': '부피', 'children': {'03-03-06-01': '부피 단위 이해하기'}}}}, '03-04': {'name': '시각과 시간', 'children': {'03-04-01': {'name': '시각', 'children': {'03-04-01-01': '시계 읽기', '03-04-01-02': '초 단위까지 시각 읽기'}}, '03-04-02': {'name': '시간', 'children': {'03-04-02-01': '시간과 분의 관계 이해하기', '03-04-02-02': '1분, 1시간, 1일, 1주일, 1개월, 1 ...
# 그래프 생성 완료
# 노드 추가: 03 - 도형과 측정
# 노드 추가: 03-01 - 입체도형
# 엣지 추가: 03 -> 03-01
# 노드 추가: 03-01-02 - 직육면체의 모양
# 엣지 추가: 03-01 -> 03-01-02
# 노드 추가: 03-01-02-01 - 직육면체
# 엣지 추가: 03-01-02 -> 03-01-02-01
# 노드 추가: 03-01-02-02 - 직육면체의 구성요소와 성질
# 엣지 추가: 03-01-02 -> 03-01-02-02
# 노드 추가: 03-01-02-03 - 정육면체
# 엣지 추가: 03-01-02 -> 03-01-02-03
# 노드 추가: 03-01-02-04 - 정육면체의 구성요소와 성질
# 엣지 추가: 03-01-02 -> 03-01-02-04
# 노드 추가: 03-01-02-05 - 직육면체의 겨냥도
# 엣지 추가: 03-01-02 -> 03-01-02-05
# 노드 추가: 03-01-02-06 - 직육면체의 전개도
# 엣지 추가: 03-01-02 -> 03-01-02-06
# 노드 추가: 03-01-02-07 - 정육면체의 겨냥도
# 엣지 추가: 03-01-02 -> 03-01-02-07
# 노드 추가: 03-01-02-08 - 정육면체의 전개도
# 엣지 추가: 03-01-02 -> 03-01-02-08
# 노드 추가: 03-01-02-09 - 직육면체 겉넓이 구하기
# 엣지 추가: 03-01-02 -> 03-01-02-09
# 노드 추가: 03-01-02-10 - 정육면체 겉넓이 구하기
# 엣지 추가: 03-01-02 -> 03-01-02-10
# 노드 추가: 03-01-02-11 - 직육면체의 부피 구하기
# 엣지 추가: 03-01-02 -> 03-01-02-11
# 노드 추가: 03-01-02-12 - 정육면체의 부피 구하기
# 엣지 추가: 03-01-02 -> 03-01-02-12
# 노드 추가: 03-01-03 - 원기둥의 모양
# 엣지 추가: 03-01 -> 03-01-03
# 노드 추가: 03-01-03-01 - 원기둥
# 엣지 추가: 03-01-03 -> 03-01-03-01
# 노드 추가: 03-01-03-02 - 원뿔
# 엣지 추가: 03-01-03 -> 03-01-03-02
# 노드 추가: 03-01-03-03 - 원기둥의 구성요소와 성질
# 엣지 추가: 03-01-03 -> 03-01-03-03
# 노드 추가: 03-01-03-04 - 원뿔의 구성요소와 성질
# 엣지 추가: 03-01-03 -> 03-01-03-04
# 노드 추가: 03-01-03-05 - 원기둥 전개도
# 엣지 추가: 03-01-03 -> 03-01-03-05
# 노드 추가: 03-01-04 - 구의 모양
# 엣지 추가: 03-01 -> 03-01-04
# 노드 추가: 03-01-04-01 - 구 이해하기
# 엣지 추가: 03-01-04 -> 03-01-04-01
# 노드 추가: 03-01-04-02 - 구의 구성요소와 성질
# 엣지 추가: 03-01-04 -> 03-01-04-02
# 노드 추가: 03-01-05 - 여러 모양으로 쌓기
# 엣지 추가: 03-01 -> 03-01-05
# 노드 추가: 03-01-05-01 - 모양에 대해 위치나 방향을 이용하여 말하기
# 엣지 추가: 03-01-05 -> 03-01-05-01
# 노드 추가: 03-01-05-02 - 입체도형의 쌓기나무 개수 구하기
# 엣지 추가: 03-01-05 -> 03-01-05-02
# 노드 추가: 03-01-05-03 - 입체도형의 위. 앞. 옆에서 본 모양 표현하기
# 엣지 추가: 03-01-05 -> 03-01-05-03
# 노드 추가: 03-01-05-04 - 입체도형의 모양 추론하기
# 엣지 추가: 03-01-05 -> 03-01-05-04
# 노드 추가: 03-01-07 - 각기둥
# 엣지 추가: 03-01 -> 03-01-07
# 노드 추가: 03-01-07-01 - 각기둥 이해하기
# 엣지 추가: 03-01-07 -> 03-01-07-01
# 노드 추가: 03-01-07-02 - 각기둥의 구성요소와 성질
# 엣지 추가: 03-01-07 -> 03-01-07-02
# 노드 추가: 03-01-08 - 각뿔
# 엣지 추가: 03-01 -> 03-01-08
# 노드 추가: 03-01-08-01 - 각뿔 이해하기
# 엣지 추가: 03-01-08 -> 03-01-08-01
# 노드 추가: 03-01-08-02 - 각뿔의 구성요소와 성질
# 엣지 추가: 03-01-08 -> 03-01-08-02
# 노드 추가: 03-02 - 평면도형
# 엣지 추가: 03 -> 03-02
# 노드 추가: 03-02-01 - 생활 속 여러 물건의 모양
# 엣지 추가: 03-02 -> 03-02-01
# 노드 추가: 03-02-02 - 삼각형
# 엣지 추가: 03-02 -> 03-02-02
# 노드 추가: 03-02-02-01 - 여러 가지 삼각형 분류하기
# 엣지 추가: 03-02-02 -> 03-02-02-01
# 노드 추가: 03-02-02-02 - 이등변삼각형
# 엣지 추가: 03-02-02 -> 03-02-02-02
# 노드 추가: 03-02-02-03 - 정삼각형
# 엣지 추가: 03-02-02 -> 03-02-02-03
# 노드 추가: 03-02-02-04 - 직각삼각형
# 엣지 추가: 03-02-02 -> 03-02-02-04
# 노드 추가: 03-02-02-05 - 예각삼각형
# 엣지 추가: 03-02-02 -> 03-02-02-05
# 노드 추가: 03-02-02-06 - 둔각삼각형
# 엣지 추가: 03-02-02 -> 03-02-02-06
# 노드 추가: 03-02-03 - 사각형
# 엣지 추가: 03-02 -> 03-02-03
# 노드 추가: 03-02-03-01 - 여러 가지 사각형 분류하기
# 엣지 추가: 03-02-03 -> 03-02-03-01
# 노드 추가: 03-02-03-02 - 직사각형
# 엣지 추가: 03-02-03 -> 03-02-03-02
# 노드 추가: 03-02-03-03 - 정사각형
# 엣지 추가: 03-02-03 -> 03-02-03-03
# 노드 추가: 03-02-03-04 - 사다리꼴
# 엣지 추가: 03-02-03 -> 03-02-03-04
# 노드 추가: 03-02-03-05 - 평행사변형
# 엣지 추가: 03-02-03 -> 03-02-03-05
# 노드 추가: 03-02-03-06 - 마름모
# 엣지 추가: 03-02-03 -> 03-02-03-06
# 노드 추가: 03-02-04 - 원
# 엣지 추가: 03-02 -> 03-02-04
# 노드 추가: 03-02-04-01 - 원의 중심
# 엣지 추가: 03-02-04 -> 03-02-04-01
# 노드 추가: 03-02-04-02 - 원의 반지름
# 엣지 추가: 03-02-04 -> 03-02-04-02
# 노드 추가: 03-02-04-03 - 원의 지름
# 엣지 추가: 03-02-04 -> 03-02-04-03
# 노드 추가: 03-02-04-04 - 원의 성질
# 엣지 추가: 03-02-04 -> 03-02-04-04
# 노드 추가: 03-02-04-05 - 컴퍼스를 이용해 원 그리기
# 엣지 추가: 03-02-04 -> 03-02-04-05
# 노드 추가: 03-02-04-06 - 원주와 지름 측정하기
# 엣지 추가: 03-02-04 -> 03-02-04-06
# 노드 추가: 03-02-04-07 - 원주율 이해하기
# 엣지 추가: 03-02-04 -> 03-02-04-07
# 노드 추가: 03-02-04-08 - 원주 구하기
# 엣지 추가: 03-02-04 -> 03-02-04-08
# 노드 추가: 03-02-04-09 - 원의 넓이 구하기
# 엣지 추가: 03-02-04 -> 03-02-04-09
# 노드 추가: 03-02-05 - 직선, 선분, 반직선
# 엣지 추가: 03-02 -> 03-02-05
# 노드 추가: 03-02-06 - 각
# 엣지 추가: 03-02 -> 03-02-06
# 노드 추가: 03-02-06-01 - 직각
# 엣지 추가: 03-02-06 -> 03-02-06-01
# 노드 추가: 03-02-06-02 - 예각
# 엣지 추가: 03-02-06 -> 03-02-06-02
# 노드 추가: 03-02-06-03 - 둔각
# 엣지 추가: 03-02-06 -> 03-02-06-03
# 노드 추가: 03-02-06-04 - 직선의 수직관계
# 엣지 추가: 03-02-06 -> 03-02-06-04
# 노드 추가: 03-02-06-05 - 직선의 평행관계
# 엣지 추가: 03-02-06 -> 03-02-06-05
# 노드 추가: 03-02-06-06 - 각의 단위 이해하기
# 엣지 추가: 03-02-06 -> 03-02-06-06
# 노드 추가: 03-02-06-07 - 각의 크기 측정하기
# 엣지 추가: 03-02-06 -> 03-02-06-07
# 노드 추가: 03-02-06-08 - 각의 크기 어림하기
# 엣지 추가: 03-02-06 -> 03-02-06-08
# 노드 추가: 03-02-06-09 - 삼각형의 내각의 크기의 합 추론하기
# 엣지 추가: 03-02-06 -> 03-02-06-09
# 노드 추가: 03-02-06-10 - 사각형의 내각의 크기의 합 추론하기
# 엣지 추가: 03-02-06 -> 03-02-06-10
# 노드 추가: 03-02-07 - 평면도형의 이동
# 엣지 추가: 03-02 -> 03-02-07
# 노드 추가: 03-02-07-01 - 도형 밀기, 뒤집기, 돌리기
# 엣지 추가: 03-02-07 -> 03-02-07-01
# 노드 추가: 03-02-07-02 - 평면에서의 점의 이동
# 엣지 추가: 03-02-07 -> 03-02-07-02
# 노드 추가: 03-02-07-03 - 도형의 합동 이해하기
# 엣지 추가: 03-02-07 -> 03-02-07-03
# 노드 추가: 03-02-07-04 - 합동인 도형의 성질
# 엣지 추가: 03-02-07 -> 03-02-07-04
# 노드 추가: 03-02-07-05 - 선대칭도형
# 엣지 추가: 03-02-07 -> 03-02-07-05
# 노드 추가: 03-02-07-06 - 점대칭도형
# 엣지 추가: 03-02-07 -> 03-02-07-06
# 노드 추가: 03-02-08 - 다각형과 정다각형
# 엣지 추가: 03-02 -> 03-02-08
# 노드 추가: 03-02-08-01 - 다각형
# 엣지 추가: 03-02-08 -> 03-02-08-01
# 노드 추가: 03-02-08-02 - 정다각형
# 엣지 추가: 03-02-08 -> 03-02-08-02
# 노드 추가: 03-02-08-03 - 주어진 도형으로 여러 가지 모양 만들거나 채우기
# 엣지 추가: 03-02-08 -> 03-02-08-03
# 노드 추가: 03-02-08-04 - 평면도형의 둘레
# 엣지 추가: 03-02-08 -> 03-02-08-04
# 노드 추가: 03-02-08-05 - 직사각형의 넓이
# 엣지 추가: 03-02-08 -> 03-02-08-05
# 노드 추가: 03-02-08-06 - 정사각형의 넓이
# 엣지 추가: 03-02-08 -> 03-02-08-06
# 노드 추가: 03-02-08-07 - 사다리꼴의 넓이
# 엣지 추가: 03-02-08 -> 03-02-08-07
# 노드 추가: 03-02-08-08 - 평행사변형의 넓이
# 엣지 추가: 03-02-08 -> 03-02-08-08
# 노드 추가: 03-02-08-09 - 마름모의 넓이
# 엣지 추가: 03-02-08 -> 03-02-08-09
# 노드 추가: 03-03 - 양의 비교
# 엣지 추가: 03 -> 03-03
# 노드 추가: 03-03-01 - 길이
# 엣지 추가: 03-03 -> 03-03-01
# 노드 추가: 03-03-01-01 - 길이 단위 이해하기
# 엣지 추가: 03-03-01 -> 03-03-01-01
# 노드 추가: 03-03-01-02 - 길이 측정하기
# 엣지 추가: 03-03-01 -> 03-03-01-02
# 노드 추가: 03-03-01-03 - 1m와 1cm의 관계 이해하기
# 엣지 추가: 03-03-01 -> 03-03-01-03
# 노드 추가: 03-03-01-04 - 물건의 길이 어림하기
# 엣지 추가: 03-03-01 -> 03-03-01-04
# 노드 추가: 03-03-01-05 - 길이의 덧셈
# 엣지 추가: 03-03-01 -> 03-03-01-05
# 노드 추가: 03-03-01-06 - 길이의 뺄셈
# 엣지 추가: 03-03-01 -> 03-03-01-06
# 노드 추가: 03-03-01-07 - 1mm
# 엣지 추가: 03-03-01 -> 03-03-01-07
# 노드 추가: 03-03-01-08 - 1km
# 엣지 추가: 03-03-01 -> 03-03-01-08
# 노드 추가: 03-03-01-09 - 길이 측정하기
# 엣지 추가: 03-03-01 -> 03-03-01-09
# 노드 추가: 03-03-01-10 - 길이 어림하기
# 엣지 추가: 03-03-01 -> 03-03-01-10
# 노드 추가: 03-03-01-11 - 길이의 관계 이해하기
# 엣지 추가: 03-03-01 -> 03-03-01-11
# 노드 추가: 03-03-02 - 들이
# 엣지 추가: 03-03 -> 03-03-02
# 노드 추가: 03-03-02-01 - 들이 단위 이해하기
# 엣지 추가: 03-03-02 -> 03-03-02-01
# 노드 추가: 03-03-02-02 - 들이 측정하기
# 엣지 추가: 03-03-02 -> 03-03-02-02
# 노드 추가: 03-03-02-03 - 들이 어림하기
# 엣지 추가: 03-03-02 -> 03-03-02-03
# 노드 추가: 03-03-02-04 - 1L와 1mL의 관계 이해하기
# 엣지 추가: 03-03-02 -> 03-03-02-04
# 노드 추가: 03-03-02-05 - 들이의 덧셈
# 엣지 추가: 03-03-02 -> 03-03-02-05
# 노드 추가: 03-03-02-06 - 들이의 뺄셈
# 엣지 추가: 03-03-02 -> 03-03-02-06
# 노드 추가: 03-03-03 - 무게
# 엣지 추가: 03-03 -> 03-03-03
# 노드 추가: 03-03-03-01 - 무게 단위 이해하기
# 엣지 추가: 03-03-03 -> 03-03-03-01
# 노드 추가: 03-03-03-02 - 무게 측정하기
# 엣지 추가: 03-03-03 -> 03-03-03-02
# 노드 추가: 03-03-03-03 - 무게 어림하기
# 엣지 추가: 03-03-03 -> 03-03-03-03
# 노드 추가: 03-03-03-04 - 1kg와 1g의 관계 이해하기
# 엣지 추가: 03-03-03 -> 03-03-03-04
# 노드 추가: 03-03-03-05 - 1kg와 1t의 관계 이해하기
# 엣지 추가: 03-03-03 -> 03-03-03-05
# 노드 추가: 03-03-03-06 - 무게의 덧셈
# 엣지 추가: 03-03-03 -> 03-03-03-06
# 노드 추가: 03-03-03-07 - 무게의 뺄셈
# 엣지 추가: 03-03-03 -> 03-03-03-07
# 노드 추가: 03-03-04 - 넓이
# 엣지 추가: 03-03 -> 03-03-04
# 노드 추가: 03-03-04-01 - 넓이 단위 이해하기
# 엣지 추가: 03-03-04 -> 03-03-04-01
# 노드 추가: 03-03-06 - 부피
# 엣지 추가: 03-03 -> 03-03-06
# 노드 추가: 03-03-06-01 - 부피 단위 이해하기
# 엣지 추가: 03-03-06 -> 03-03-06-01
# 노드 추가: 03-04 - 시각과 시간
# 엣지 추가: 03 -> 03-04
# 노드 추가: 03-04-01 - 시각
# 엣지 추가: 03-04 -> 03-04-01
# 노드 추가: 03-04-01-01 - 시계 읽기
# 엣지 추가: 03-04-01 -> 03-04-01-01
# 노드 추가: 03-04-01-02 - 초 단위까지 시각 읽기
# 엣지 추가: 03-04-01 -> 03-04-01-02
# 노드 추가: 03-04-02 - 시간
# 엣지 추가: 03-04 -> 03-04-02
# 노드 추가: 03-04-02-01 - 시간과 분의 관계 이해하기
# 엣지 추가: 03-04-02 -> 03-04-02-01
# 노드 추가: 03-04-02-02 - 1분, 1시간, 1일, 1주일, 1개월, 1년 사이의 관계 이해하기
# 엣지 추가: 03-04-02 -> 03-04-02-02
# 노드 추가: 03-04-02-03 - 1분과 1초의 관계
# 엣지 추가: 03-04-02 -> 03-04-02-03
# 노드 추가: 03-04-02-04 - 시간의 덧셈
# 엣지 추가: 03-04-02 -> 03-04-02-04
# 노드 추가: 03-04-02-05 - 시간의 뺄셈
# 엣지 추가: 03-04-02 -> 03-04-02-05
# 노드 및 엣지 추가 완료
# 노드 레이블 설정 완료
# 비슷한 키워드로 엣지 추가: 03 -> 03-02-04-06
# 비슷한 키워드로 엣지 추가: 03 -> 03-02-06-07
# 비슷한 키워드로 엣지 추가: 03 -> 03-02-07-01
# 비슷한 키워드로 엣지 추가: 03 -> 03-02-07-03
# 비슷한 키워드로 엣지 추가: 03 -> 03-02-07-04
# 비슷한 키워드로 엣지 추가: 03 -> 03-02-08-03
# 비슷한 키워드로 엣지 추가: 03 -> 03-03-01-02
# 비슷한 키워드로 엣지 추가: 03 -> 03-03-01-09
# 비슷한 키워드로 엣지 추가: 03 -> 03-03-02-02
# 비슷한 키워드로 엣지 추가: 03 -> 03-03-03-02
# 비슷한 키워드로 엣지 추가: 03-01 -> 03-01-05-02
# 비슷한 키워드로 엣지 추가: 03-01 -> 03-01-05-03
# 비슷한 키워드로 엣지 추가: 03-01 -> 03-01-05-04
# 비슷한 키워드로 엣지 추가: 03-01-02 -> 03-01-02-01
# 비슷한 키워드로 엣지 추가: 03-01-02 -> 03-01-02-02
# 비슷한 키워드로 엣지 추가: 03-01-02 -> 03-01-02-05
# 비슷한 키워드로 엣지 추가: 03-01-02 -> 03-01-02-06
# 비슷한 키워드로 엣지 추가: 03-01-02 -> 03-01-02-09
# 비슷한 키워드로 엣지 추가: 03-01-02 -> 03-01-02-11
# 비슷한 키워드로 엣지 추가: 03-01-02 -> 03-01-03
# 비슷한 키워드로 엣지 추가: 03-01-02 -> 03-01-04
# 비슷한 키워드로 엣지 추가: 03-01-02 -> 03-01-05
# 비슷한 키워드로 엣지 추가: 03-01-02 -> 03-01-05-01
# 비슷한 키워드로 엣지 추가: 03-01-02 -> 03-01-05-03
# 비슷한 키워드로 엣지 추가: 03-01-02 -> 03-01-05-04
# 비슷한 키워드로 엣지 추가: 03-01-02 -> 03-02-01
# 비슷한 키워드로 엣지 추가: 03-01-02 -> 03-02-08-03
# 비슷한 키워드로 엣지 추가: 03-01-02-01 -> 03-01-02-02
# 비슷한 키워드로 엣지 추가: 03-01-02-01 -> 03-01-02-05
# 비슷한 키워드로 엣지 추가: 03-01-02-01 -> 03-01-02-06
# 비슷한 키워드로 엣지 추가: 03-01-02-01 -> 03-01-02-09
# 비슷한 키워드로 엣지 추가: 03-01-02-01 -> 03-01-02-11
# 비슷한 키워드로 엣지 추가: 03-01-02-02 -> 03-01-02-04
# 비슷한 키워드로 엣지 추가: 03-01-02-02 -> 03-01-02-05
# 비슷한 키워드로 엣지 추가: 03-01-02-02 -> 03-01-02-06
# 비슷한 키워드로 엣지 추가: 03-01-02-02 -> 03-01-02-09
# 비슷한 키워드로 엣지 추가: 03-01-02-02 -> 03-01-02-11
# 비슷한 키워드로 엣지 추가: 03-01-02-02 -> 03-01-03-03
# 비슷한 키워드로 엣지 추가: 03-01-02-02 -> 03-01-03-04
# 비슷한 키워드로 엣지 추가: 03-01-02-02 -> 03-01-04-02
# 비슷한 키워드로 엣지 추가: 03-01-02-02 -> 03-01-07-02
# 비슷한 키워드로 엣지 추가: 03-01-02-02 -> 03-01-08-02
# 비슷한 키워드로 엣지 추가: 03-01-02-02 -> 03-02-04-04
# 비슷한 키워드로 엣지 추가: 03-01-02-02 -> 03-02-07-04
# 비슷한 키워드로 엣지 추가: 03-01-02-03 -> 03-01-02-04
# 비슷한 키워드로 엣지 추가: 03-01-02-03 -> 03-01-02-07
# 비슷한 키워드로 엣지 추가: 03-01-02-03 -> 03-01-02-08
# 비슷한 키워드로 엣지 추가: 03-01-02-03 -> 03-01-02-10
# 비슷한 키워드로 엣지 추가: 03-01-02-03 -> 03-01-02-12
# 비슷한 키워드로 엣지 추가: 03-01-02-04 -> 03-01-02-07
# 비슷한 키워드로 엣지 추가: 03-01-02-04 -> 03-01-02-08
# 비슷한 키워드로 엣지 추가: 03-01-02-04 -> 03-01-02-10
# 비슷한 키워드로 엣지 추가: 03-01-02-04 -> 03-01-02-12
# 비슷한 키워드로 엣지 추가: 03-01-02-04 -> 03-01-03-03
# 비슷한 키워드로 엣지 추가: 03-01-02-04 -> 03-01-03-04
# 비슷한 키워드로 엣지 추가: 03-01-02-04 -> 03-01-04-02
# 비슷한 키워드로 엣지 추가: 03-01-02-04 -> 03-01-07-02
# 비슷한 키워드로 엣지 추가: 03-01-02-04 -> 03-01-08-02
# 비슷한 키워드로 엣지 추가: 03-01-02-04 -> 03-02-04-04
# 비슷한 키워드로 엣지 추가: 03-01-02-04 -> 03-02-07-04
# 비슷한 키워드로 엣지 추가: 03-01-02-05 -> 03-01-02-06
# 비슷한 키워드로 엣지 추가: 03-01-02-05 -> 03-01-02-07
# 비슷한 키워드로 엣지 추가: 03-01-02-05 -> 03-01-02-09
# 비슷한 키워드로 엣지 추가: 03-01-02-05 -> 03-01-02-11
# 비슷한 키워드로 엣지 추가: 03-01-02-06 -> 03-01-02-08
# 비슷한 키워드로 엣지 추가: 03-01-02-06 -> 03-01-02-09
# 비슷한 키워드로 엣지 추가: 03-01-02-06 -> 03-01-02-11
# 비슷한 키워드로 엣지 추가: 03-01-02-06 -> 03-01-03-05
# 비슷한 키워드로 엣지 추가: 03-01-02-07 -> 03-01-02-08
# 비슷한 키워드로 엣지 추가: 03-01-02-07 -> 03-01-02-10
# 비슷한 키워드로 엣지 추가: 03-01-02-07 -> 03-01-02-12
# 비슷한 키워드로 엣지 추가: 03-01-02-08 -> 03-01-02-10
# 비슷한 키워드로 엣지 추가: 03-01-02-08 -> 03-01-02-12
# 비슷한 키워드로 엣지 추가: 03-01-02-08 -> 03-01-03-05
# 비슷한 키워드로 엣지 추가: 03-01-02-09 -> 03-01-02-10
# 비슷한 키워드로 엣지 추가: 03-01-02-09 -> 03-01-02-11
# 비슷한 키워드로 엣지 추가: 03-01-02-09 -> 03-01-02-12
# 비슷한 키워드로 엣지 추가: 03-01-02-09 -> 03-01-04-01
# 비슷한 키워드로 엣지 추가: 03-01-02-09 -> 03-01-05-02
# 비슷한 키워드로 엣지 추가: 03-01-02-09 -> 03-02-04-08
# 비슷한 키워드로 엣지 추가: 03-01-02-09 -> 03-02-04-09
# 비슷한 키워드로 엣지 추가: 03-01-02-10 -> 03-01-02-11
# 비슷한 키워드로 엣지 추가: 03-01-02-10 -> 03-01-02-12
# 비슷한 키워드로 엣지 추가: 03-01-02-10 -> 03-01-04-01
# 비슷한 키워드로 엣지 추가: 03-01-02-10 -> 03-01-05-02
# 비슷한 키워드로 엣지 추가: 03-01-02-10 -> 03-02-04-08
# 비슷한 키워드로 엣지 추가: 03-01-02-10 -> 03-02-04-09
# 비슷한 키워드로 엣지 추가: 03-01-02-11 -> 03-01-02-12
# 비슷한 키워드로 엣지 추가: 03-01-02-11 -> 03-01-04-01
# 비슷한 키워드로 엣지 추가: 03-01-02-11 -> 03-01-05-02
# 비슷한 키워드로 엣지 추가: 03-01-02-11 -> 03-02-04-08
# 비슷한 키워드로 엣지 추가: 03-01-02-11 -> 03-02-04-09
# 비슷한 키워드로 엣지 추가: 03-01-02-11 -> 03-03-06
# 비슷한 키워드로 엣지 추가: 03-01-02-11 -> 03-03-06-01
# 비슷한 키워드로 엣지 추가: 03-01-02-12 -> 03-01-04-01
# 비슷한 키워드로 엣지 추가: 03-01-02-12 -> 03-01-05-02
# 비슷한 키워드로 엣지 추가: 03-01-02-12 -> 03-02-04-08
# 비슷한 키워드로 엣지 추가: 03-01-02-12 -> 03-02-04-09
# 비슷한 키워드로 엣지 추가: 03-01-02-12 -> 03-03-06
# 비슷한 키워드로 엣지 추가: 03-01-02-12 -> 03-03-06-01
# 비슷한 키워드로 엣지 추가: 03-01-03 -> 03-01-03-01
# 비슷한 키워드로 엣지 추가: 03-01-03 -> 03-01-03-03
# 비슷한 키워드로 엣지 추가: 03-01-03 -> 03-01-03-05
# 비슷한 키워드로 엣지 추가: 03-01-03 -> 03-01-04
# 비슷한 키워드로 엣지 추가: 03-01-03 -> 03-01-05
# 비슷한 키워드로 엣지 추가: 03-01-03 -> 03-01-05-01
# 비슷한 키워드로 엣지 추가: 03-01-03 -> 03-01-05-03
# 비슷한 키워드로 엣지 추가: 03-01-03 -> 03-01-05-04
# 비슷한 키워드로 엣지 추가: 03-01-03 -> 03-02-01
# 비슷한 키워드로 엣지 추가: 03-01-03 -> 03-02-08-03
# 비슷한 키워드로 엣지 추가: 03-01-03-01 -> 03-01-03-03
# 비슷한 키워드로 엣지 추가: 03-01-03-01 -> 03-01-03-05
# 비슷한 키워드로 엣지 추가: 03-01-03-02 -> 03-01-03-04
# 비슷한 키워드로 엣지 추가: 03-01-03-03 -> 03-01-03-04
# 비슷한 키워드로 엣지 추가: 03-01-03-03 -> 03-01-03-05
# 비슷한 키워드로 엣지 추가: 03-01-03-03 -> 03-01-04-02
# 비슷한 키워드로 엣지 추가: 03-01-03-03 -> 03-01-07-02
# 비슷한 키워드로 엣지 추가: 03-01-03-03 -> 03-01-08-02
# 비슷한 키워드로 엣지 추가: 03-01-03-03 -> 03-02-04-04
# 비슷한 키워드로 엣지 추가: 03-01-03-03 -> 03-02-07-04
# 비슷한 키워드로 엣지 추가: 03-01-03-04 -> 03-01-04-02
# 비슷한 키워드로 엣지 추가: 03-01-03-04 -> 03-01-07-02
# 비슷한 키워드로 엣지 추가: 03-01-03-04 -> 03-01-08-02
# 비슷한 키워드로 엣지 추가: 03-01-03-04 -> 03-02-04-04
# 비슷한 키워드로 엣지 추가: 03-01-03-04 -> 03-02-07-04
# 비슷한 키워드로 엣지 추가: 03-01-04 -> 03-01-04-02
# 비슷한 키워드로 엣지 추가: 03-01-04 -> 03-01-05
# 비슷한 키워드로 엣지 추가: 03-01-04 -> 03-01-05-01
# 비슷한 키워드로 엣지 추가: 03-01-04 -> 03-01-05-03
# 비슷한 키워드로 엣지 추가: 03-01-04 -> 03-01-05-04
# 비슷한 키워드로 엣지 추가: 03-01-04 -> 03-02-01
# 비슷한 키워드로 엣지 추가: 03-01-04 -> 03-02-08-03
# 비슷한 키워드로 엣지 추가: 03-01-04-01 -> 03-01-05-02
# 비슷한 키워드로 엣지 추가: 03-01-04-01 -> 03-01-07-01
# 비슷한 키워드로 엣지 추가: 03-01-04-01 -> 03-01-08-01
# 비슷한 키워드로 엣지 추가: 03-01-04-01 -> 03-02-04-07
# 비슷한 키워드로 엣지 추가: 03-01-04-01 -> 03-02-04-08
# 비슷한 키워드로 엣지 추가: 03-01-04-01 -> 03-02-04-09
# 비슷한 키워드로 엣지 추가: 03-01-04-01 -> 03-02-06-06
# 비슷한 키워드로 엣지 추가: 03-01-04-01 -> 03-02-07-03
# 비슷한 키워드로 엣지 추가: 03-01-04-01 -> 03-03-01-01
# 비슷한 키워드로 엣지 추가: 03-01-04-01 -> 03-03-01-03
# 비슷한 키워드로 엣지 추가: 03-01-04-01 -> 03-03-01-11
# 비슷한 키워드로 엣지 추가: 03-01-04-01 -> 03-03-02-01
# 비슷한 키워드로 엣지 추가: 03-01-04-01 -> 03-03-02-04
# 비슷한 키워드로 엣지 추가: 03-01-04-01 -> 03-03-03-01
# 비슷한 키워드로 엣지 추가: 03-01-04-01 -> 03-03-03-04
# 비슷한 키워드로 엣지 추가: 03-01-04-01 -> 03-03-03-05
# 비슷한 키워드로 엣지 추가: 03-01-04-01 -> 03-03-04-01
# 비슷한 키워드로 엣지 추가: 03-01-04-01 -> 03-03-06-01
# 비슷한 키워드로 엣지 추가: 03-01-04-01 -> 03-04-02-01
# 비슷한 키워드로 엣지 추가: 03-01-04-01 -> 03-04-02-02
# 비슷한 키워드로 엣지 추가: 03-01-04-02 -> 03-01-07-02
# 비슷한 키워드로 엣지 추가: 03-01-04-02 -> 03-01-08-02
# 비슷한 키워드로 엣지 추가: 03-01-04-02 -> 03-02-04-04
# 비슷한 키워드로 엣지 추가: 03-01-04-02 -> 03-02-07-04
# 비슷한 키워드로 엣지 추가: 03-01-05 -> 03-01-05-01
# 비슷한 키워드로 엣지 추가: 03-01-05 -> 03-01-05-03
# 비슷한 키워드로 엣지 추가: 03-01-05 -> 03-01-05-04
# 비슷한 키워드로 엣지 추가: 03-01-05 -> 03-02-01
# 비슷한 키워드로 엣지 추가: 03-01-05 -> 03-02-02-01
# 비슷한 키워드로 엣지 추가: 03-01-05 -> 03-02-03-01
# 비슷한 키워드로 엣지 추가: 03-01-05 -> 03-02-08-03
# 비슷한 키워드로 엣지 추가: 03-01-05-01 -> 03-01-05-03
# 비슷한 키워드로 엣지 추가: 03-01-05-01 -> 03-01-05-04
# 비슷한 키워드로 엣지 추가: 03-01-05-01 -> 03-02-01
# 비슷한 키워드로 엣지 추가: 03-01-05-01 -> 03-02-04-05
# 비슷한 키워드로 엣지 추가: 03-01-05-01 -> 03-02-08-03
# 비슷한 키워드로 엣지 추가: 03-01-05-02 -> 03-01-05-03
# 비슷한 키워드로 엣지 추가: 03-01-05-02 -> 03-01-05-04
# 비슷한 키워드로 엣지 추가: 03-01-05-02 -> 03-02-04-08
# 비슷한 키워드로 엣지 추가: 03-01-05-02 -> 03-02-04-09
# 비슷한 키워드로 엣지 추가: 03-01-05-03 -> 03-01-05-04
# 비슷한 키워드로 엣지 추가: 03-01-05-03 -> 03-02-01
# 비슷한 키워드로 엣지 추가: 03-01-05-03 -> 03-02-08-03
# 비슷한 키워드로 엣지 추가: 03-01-05-04 -> 03-02-01
# 비슷한 키워드로 엣지 추가: 03-01-05-04 -> 03-02-06-09
# 비슷한 키워드로 엣지 추가: 03-01-05-04 -> 03-02-06-10
# 비슷한 키워드로 엣지 추가: 03-01-05-04 -> 03-02-08-03
# 비슷한 키워드로 엣지 추가: 03-01-07 -> 03-01-07-01
# 비슷한 키워드로 엣지 추가: 03-01-07 -> 03-01-07-02
# 비슷한 키워드로 엣지 추가: 03-01-07-01 -> 03-01-07-02
# 비슷한 키워드로 엣지 추가: 03-01-07-01 -> 03-01-08-01
# 비슷한 키워드로 엣지 추가: 03-01-07-01 -> 03-02-04-07
# 비슷한 키워드로 엣지 추가: 03-01-07-01 -> 03-02-06-06
# 비슷한 키워드로 엣지 추가: 03-01-07-01 -> 03-02-07-03
# 비슷한 키워드로 엣지 추가: 03-01-07-01 -> 03-03-01-01
# 비슷한 키워드로 엣지 추가: 03-01-07-01 -> 03-03-01-03
# 비슷한 키워드로 엣지 추가: 03-01-07-01 -> 03-03-01-11
# 비슷한 키워드로 엣지 추가: 03-01-07-01 -> 03-03-02-01
# 비슷한 키워드로 엣지 추가: 03-01-07-01 -> 03-03-02-04
# 비슷한 키워드로 엣지 추가: 03-01-07-01 -> 03-03-03-01
# 비슷한 키워드로 엣지 추가: 03-01-07-01 -> 03-03-03-04
# 비슷한 키워드로 엣지 추가: 03-01-07-01 -> 03-03-03-05
# 비슷한 키워드로 엣지 추가: 03-01-07-01 -> 03-03-04-01
# 비슷한 키워드로 엣지 추가: 03-01-07-01 -> 03-03-06-01
# 비슷한 키워드로 엣지 추가: 03-01-07-01 -> 03-04-02-01
# 비슷한 키워드로 엣지 추가: 03-01-07-01 -> 03-04-02-02
# 비슷한 키워드로 엣지 추가: 03-01-07-02 -> 03-01-08-02
# 비슷한 키워드로 엣지 추가: 03-01-07-02 -> 03-02-04-04
# 비슷한 키워드로 엣지 추가: 03-01-07-02 -> 03-02-07-04
# 비슷한 키워드로 엣지 추가: 03-01-08 -> 03-01-08-01
# 비슷한 키워드로 엣지 추가: 03-01-08 -> 03-01-08-02
# 비슷한 키워드로 엣지 추가: 03-01-08-01 -> 03-01-08-02
# 비슷한 키워드로 엣지 추가: 03-01-08-01 -> 03-02-04-07
# 비슷한 키워드로 엣지 추가: 03-01-08-01 -> 03-02-06-06
# 비슷한 키워드로 엣지 추가: 03-01-08-01 -> 03-02-07-03
# 비슷한 키워드로 엣지 추가: 03-01-08-01 -> 03-03-01-01
# 비슷한 키워드로 엣지 추가: 03-01-08-01 -> 03-03-01-03
# 비슷한 키워드로 엣지 추가: 03-01-08-01 -> 03-03-01-11
# 비슷한 키워드로 엣지 추가: 03-01-08-01 -> 03-03-02-01
# 비슷한 키워드로 엣지 추가: 03-01-08-01 -> 03-03-02-04
# 비슷한 키워드로 엣지 추가: 03-01-08-01 -> 03-03-03-01
# 비슷한 키워드로 엣지 추가: 03-01-08-01 -> 03-03-03-04
# 비슷한 키워드로 엣지 추가: 03-01-08-01 -> 03-03-03-05
# 비슷한 키워드로 엣지 추가: 03-01-08-01 -> 03-03-04-01
# 비슷한 키워드로 엣지 추가: 03-01-08-01 -> 03-03-06-01
# 비슷한 키워드로 엣지 추가: 03-01-08-01 -> 03-04-02-01
# 비슷한 키워드로 엣지 추가: 03-01-08-01 -> 03-04-02-02
# 비슷한 키워드로 엣지 추가: 03-01-08-02 -> 03-02-04-04
# 비슷한 키워드로 엣지 추가: 03-01-08-02 -> 03-02-07-04
# 비슷한 키워드로 엣지 추가: 03-02 -> 03-02-07
# 비슷한 키워드로 엣지 추가: 03-02 -> 03-02-08-04
# 비슷한 키워드로 엣지 추가: 03-02-01 -> 03-02-02-01
# 비슷한 키워드로 엣지 추가: 03-02-01 -> 03-02-03-01
# 비슷한 키워드로 엣지 추가: 03-02-01 -> 03-02-08-03
# 비슷한 키워드로 엣지 추가: 03-02-01 -> 03-03-01-04
# 비슷한 키워드로 엣지 추가: 03-02-02 -> 03-02-02-01
# 비슷한 키워드로 엣지 추가: 03-02-02 -> 03-02-06-09
# 비슷한 키워드로 엣지 추가: 03-02-02-01 -> 03-02-03-01
# 비슷한 키워드로 엣지 추가: 03-02-02-01 -> 03-02-06-09
# 비슷한 키워드로 엣지 추가: 03-02-02-01 -> 03-02-08-03
# 비슷한 키워드로 엣지 추가: 03-02-03 -> 03-02-03-01
# 비슷한 키워드로 엣지 추가: 03-02-03 -> 03-02-06-10
# 비슷한 키워드로 엣지 추가: 03-02-03-01 -> 03-02-06-10
# 비슷한 키워드로 엣지 추가: 03-02-03-01 -> 03-02-08-03
# 비슷한 키워드로 엣지 추가: 03-02-03-02 -> 03-02-08-05
# 비슷한 키워드로 엣지 추가: 03-02-03-03 -> 03-02-08-06
# 비슷한 키워드로 엣지 추가: 03-02-03-04 -> 03-02-08-07
# 비슷한 키워드로 엣지 추가: 03-02-03-05 -> 03-02-08-08
# 비슷한 키워드로 엣지 추가: 03-02-03-06 -> 03-02-08-09
# 비슷한 키워드로 엣지 추가: 03-02-04 -> 03-02-04-01
# 비슷한 키워드로 엣지 추가: 03-02-04 -> 03-02-04-02
# 비슷한 키워드로 엣지 추가: 03-02-04 -> 03-02-04-03
# 비슷한 키워드로 엣지 추가: 03-02-04 -> 03-02-04-04
# 비슷한 키워드로 엣지 추가: 03-02-04 -> 03-02-04-05
# 비슷한 키워드로 엣지 추가: 03-02-04 -> 03-02-04-09
# 비슷한 키워드로 엣지 추가: 03-02-04-01 -> 03-02-04-02
# 비슷한 키워드로 엣지 추가: 03-02-04-01 -> 03-02-04-03
# 비슷한 키워드로 엣지 추가: 03-02-04-01 -> 03-02-04-04
# 비슷한 키워드로 엣지 추가: 03-02-04-01 -> 03-02-04-05
# 비슷한 키워드로 엣지 추가: 03-02-04-01 -> 03-02-04-09
# 비슷한 키워드로 엣지 추가: 03-02-04-02 -> 03-02-04-03
# 비슷한 키워드로 엣지 추가: 03-02-04-02 -> 03-02-04-04
# 비슷한 키워드로 엣지 추가: 03-02-04-02 -> 03-02-04-05
# 비슷한 키워드로 엣지 추가: 03-02-04-02 -> 03-02-04-09
# 비슷한 키워드로 엣지 추가: 03-02-04-03 -> 03-02-04-04
# 비슷한 키워드로 엣지 추가: 03-02-04-03 -> 03-02-04-05
# 비슷한 키워드로 엣지 추가: 03-02-04-03 -> 03-02-04-06
# 비슷한 키워드로 엣지 추가: 03-02-04-03 -> 03-02-04-09
# 비슷한 키워드로 엣지 추가: 03-02-04-04 -> 03-02-04-05
# 비슷한 키워드로 엣지 추가: 03-02-04-04 -> 03-02-04-09
# 비슷한 키워드로 엣지 추가: 03-02-04-04 -> 03-02-07-04
# 비슷한 키워드로 엣지 추가: 03-02-04-05 -> 03-02-04-09
# 비슷한 키워드로 엣지 추가: 03-02-04-06 -> 03-02-04-08
# 비슷한 키워드로 엣지 추가: 03-02-04-06 -> 03-02-06-07
# 비슷한 키워드로 엣지 추가: 03-02-04-06 -> 03-03-01-02
# 비슷한 키워드로 엣지 추가: 03-02-04-06 -> 03-03-01-09
# 비슷한 키워드로 엣지 추가: 03-02-04-06 -> 03-03-02-02
# 비슷한 키워드로 엣지 추가: 03-02-04-06 -> 03-03-03-02
# 비슷한 키워드로 엣지 추가: 03-02-04-07 -> 03-02-06-06
# 비슷한 키워드로 엣지 추가: 03-02-04-07 -> 03-02-07-03
# 비슷한 키워드로 엣지 추가: 03-02-04-07 -> 03-03-01-01
# 비슷한 키워드로 엣지 추가: 03-02-04-07 -> 03-03-01-03
# 비슷한 키워드로 엣지 추가: 03-02-04-07 -> 03-03-01-11
# 비슷한 키워드로 엣지 추가: 03-02-04-07 -> 03-03-02-01
# 비슷한 키워드로 엣지 추가: 03-02-04-07 -> 03-03-02-04
# 비슷한 키워드로 엣지 추가: 03-02-04-07 -> 03-03-03-01
# 비슷한 키워드로 엣지 추가: 03-02-04-07 -> 03-03-03-04
# 비슷한 키워드로 엣지 추가: 03-02-04-07 -> 03-03-03-05
# 비슷한 키워드로 엣지 추가: 03-02-04-07 -> 03-03-04-01
# 비슷한 키워드로 엣지 추가: 03-02-04-07 -> 03-03-06-01
# 비슷한 키워드로 엣지 추가: 03-02-04-07 -> 03-04-02-01
# 비슷한 키워드로 엣지 추가: 03-02-04-07 -> 03-04-02-02
# 비슷한 키워드로 엣지 추가: 03-02-04-08 -> 03-02-04-09
# 비슷한 키워드로 엣지 추가: 03-02-04-09 -> 03-02-08-05
# 비슷한 키워드로 엣지 추가: 03-02-04-09 -> 03-02-08-06
# 비슷한 키워드로 엣지 추가: 03-02-04-09 -> 03-02-08-07
# 비슷한 키워드로 엣지 추가: 03-02-04-09 -> 03-02-08-08
# 비슷한 키워드로 엣지 추가: 03-02-04-09 -> 03-02-08-09
# 비슷한 키워드로 엣지 추가: 03-02-04-09 -> 03-03-04
# 비슷한 키워드로 엣지 추가: 03-02-04-09 -> 03-03-04-01
# 비슷한 키워드로 엣지 추가: 03-02-05 -> 03-02-06-04
# 비슷한 키워드로 엣지 추가: 03-02-05 -> 03-02-06-05
# 비슷한 키워드로 엣지 추가: 03-02-06-04 -> 03-02-06-05
# 비슷한 키워드로 엣지 추가: 03-02-06-04 -> 03-03-01-03
# 비슷한 키워드로 엣지 추가: 03-02-06-04 -> 03-03-01-11
# 비슷한 키워드로 엣지 추가: 03-02-06-04 -> 03-03-02-04
# 비슷한 키워드로 엣지 추가: 03-02-06-04 -> 03-03-03-04
# 비슷한 키워드로 엣지 추가: 03-02-06-04 -> 03-03-03-05
# 비슷한 키워드로 엣지 추가: 03-02-06-04 -> 03-04-02-01
# 비슷한 키워드로 엣지 추가: 03-02-06-04 -> 03-04-02-02
# 비슷한 키워드로 엣지 추가: 03-02-06-04 -> 03-04-02-03
# 비슷한 키워드로 엣지 추가: 03-02-06-05 -> 03-03-01-03
# 비슷한 키워드로 엣지 추가: 03-02-06-05 -> 03-03-01-11
# 비슷한 키워드로 엣지 추가: 03-02-06-05 -> 03-03-02-04
# 비슷한 키워드로 엣지 추가: 03-02-06-05 -> 03-03-03-04
# 비슷한 키워드로 엣지 추가: 03-02-06-05 -> 03-03-03-05
# 비슷한 키워드로 엣지 추가: 03-02-06-05 -> 03-04-02-01
# 비슷한 키워드로 엣지 추가: 03-02-06-05 -> 03-04-02-02
# 비슷한 키워드로 엣지 추가: 03-02-06-05 -> 03-04-02-03
# 비슷한 키워드로 엣지 추가: 03-02-06-06 -> 03-02-06-07
# 비슷한 키워드로 엣지 추가: 03-02-06-06 -> 03-02-06-08
# 비슷한 키워드로 엣지 추가: 03-02-06-06 -> 03-02-07-03
# 비슷한 키워드로 엣지 추가: 03-02-06-06 -> 03-03-01-01
# 비슷한 키워드로 엣지 추가: 03-02-06-06 -> 03-03-01-03
# 비슷한 키워드로 엣지 추가: 03-02-06-06 -> 03-03-01-11
# 비슷한 키워드로 엣지 추가: 03-02-06-06 -> 03-03-02-01
# 비슷한 키워드로 엣지 추가: 03-02-06-06 -> 03-03-02-04
# 비슷한 키워드로 엣지 추가: 03-02-06-06 -> 03-03-03-01
# 비슷한 키워드로 엣지 추가: 03-02-06-06 -> 03-03-03-04
# 비슷한 키워드로 엣지 추가: 03-02-06-06 -> 03-03-03-05
# 비슷한 키워드로 엣지 추가: 03-02-06-06 -> 03-03-04-01
# 비슷한 키워드로 엣지 추가: 03-02-06-06 -> 03-03-06-01
# 비슷한 키워드로 엣지 추가: 03-02-06-06 -> 03-04-01-02
# 비슷한 키워드로 엣지 추가: 03-02-06-06 -> 03-04-02-01
# 비슷한 키워드로 엣지 추가: 03-02-06-06 -> 03-04-02-02
# 비슷한 키워드로 엣지 추가: 03-02-06-07 -> 03-02-06-08
# 비슷한 키워드로 엣지 추가: 03-02-06-07 -> 03-02-06-09
# 비슷한 키워드로 엣지 추가: 03-02-06-07 -> 03-02-06-10
# 비슷한 키워드로 엣지 추가: 03-02-06-07 -> 03-03-01-02
# 비슷한 키워드로 엣지 추가: 03-02-06-07 -> 03-03-01-09
# 비슷한 키워드로 엣지 추가: 03-02-06-07 -> 03-03-02-02
# 비슷한 키워드로 엣지 추가: 03-02-06-07 -> 03-03-03-02
# 비슷한 키워드로 엣지 추가: 03-02-06-08 -> 03-02-06-09
# 비슷한 키워드로 엣지 추가: 03-02-06-08 -> 03-02-06-10
# 비슷한 키워드로 엣지 추가: 03-02-06-08 -> 03-03-01-04
# 비슷한 키워드로 엣지 추가: 03-02-06-08 -> 03-03-01-10
# 비슷한 키워드로 엣지 추가: 03-02-06-08 -> 03-03-02-03
# 비슷한 키워드로 엣지 추가: 03-02-06-08 -> 03-03-03-03
# 비슷한 키워드로 엣지 추가: 03-02-06-09 -> 03-02-06-10
# 비슷한 키워드로 엣지 추가: 03-02-07 -> 03-02-07-02
# 비슷한 키워드로 엣지 추가: 03-02-07 -> 03-02-08-04
# 비슷한 키워드로 엣지 추가: 03-02-07-01 -> 03-02-07-03
# 비슷한 키워드로 엣지 추가: 03-02-07-01 -> 03-02-07-04
# 비슷한 키워드로 엣지 추가: 03-02-07-01 -> 03-02-08-03
# 비슷한 키워드로 엣지 추가: 03-02-07-03 -> 03-02-07-04
# 비슷한 키워드로 엣지 추가: 03-02-07-03 -> 03-02-08-03
# 비슷한 키워드로 엣지 추가: 03-02-07-03 -> 03-03-01-01
# 비슷한 키워드로 엣지 추가: 03-02-07-03 -> 03-03-01-03
# 비슷한 키워드로 엣지 추가: 03-02-07-03 -> 03-03-01-11
# 비슷한 키워드로 엣지 추가: 03-02-07-03 -> 03-03-02-01
# 비슷한 키워드로 엣지 추가: 03-02-07-03 -> 03-03-02-04
# 비슷한 키워드로 엣지 추가: 03-02-07-03 -> 03-03-03-01
# 비슷한 키워드로 엣지 추가: 03-02-07-03 -> 03-03-03-04
# 비슷한 키워드로 엣지 추가: 03-02-07-03 -> 03-03-03-05
# 비슷한 키워드로 엣지 추가: 03-02-07-03 -> 03-03-04-01
# 비슷한 키워드로 엣지 추가: 03-02-07-03 -> 03-03-06-01
# 비슷한 키워드로 엣지 추가: 03-02-07-03 -> 03-04-02-01
# 비슷한 키워드로 엣지 추가: 03-02-07-03 -> 03-04-02-02
# 비슷한 키워드로 엣지 추가: 03-02-07-04 -> 03-02-08-03
# 비슷한 키워드로 엣지 추가: 03-02-08 -> 03-02-08-01
# 비슷한 키워드로 엣지 추가: 03-02-08 -> 03-02-08-02
# 비슷한 키워드로 엣지 추가: 03-02-08-05 -> 03-02-08-06
# 비슷한 키워드로 엣지 추가: 03-02-08-05 -> 03-02-08-07
# 비슷한 키워드로 엣지 추가: 03-02-08-05 -> 03-02-08-08
# 비슷한 키워드로 엣지 추가: 03-02-08-05 -> 03-02-08-09
# 비슷한 키워드로 엣지 추가: 03-02-08-05 -> 03-03-04
# 비슷한 키워드로 엣지 추가: 03-02-08-05 -> 03-03-04-01
# 비슷한 키워드로 엣지 추가: 03-02-08-06 -> 03-02-08-07
# 비슷한 키워드로 엣지 추가: 03-02-08-06 -> 03-02-08-08
# 비슷한 키워드로 엣지 추가: 03-02-08-06 -> 03-02-08-09
# 비슷한 키워드로 엣지 추가: 03-02-08-06 -> 03-03-04
# 비슷한 키워드로 엣지 추가: 03-02-08-06 -> 03-03-04-01
# 비슷한 키워드로 엣지 추가: 03-02-08-07 -> 03-02-08-08
# 비슷한 키워드로 엣지 추가: 03-02-08-07 -> 03-02-08-09
# 비슷한 키워드로 엣지 추가: 03-02-08-07 -> 03-03-04
# 비슷한 키워드로 엣지 추가: 03-02-08-07 -> 03-03-04-01
# 비슷한 키워드로 엣지 추가: 03-02-08-08 -> 03-02-08-09
# 비슷한 키워드로 엣지 추가: 03-02-08-08 -> 03-03-04
# 비슷한 키워드로 엣지 추가: 03-02-08-08 -> 03-03-04-01
# 비슷한 키워드로 엣지 추가: 03-02-08-09 -> 03-03-04
# 비슷한 키워드로 엣지 추가: 03-02-08-09 -> 03-03-04-01
# 비슷한 키워드로 엣지 추가: 03-03-01 -> 03-03-01-01
# 비슷한 키워드로 엣지 추가: 03-03-01 -> 03-03-01-02
# 비슷한 키워드로 엣지 추가: 03-03-01 -> 03-03-01-04
# 비슷한 키워드로 엣지 추가: 03-03-01 -> 03-03-01-05
# 비슷한 키워드로 엣지 추가: 03-03-01 -> 03-03-01-06
# 비슷한 키워드로 엣지 추가: 03-03-01 -> 03-03-01-09
# 비슷한 키워드로 엣지 추가: 03-03-01 -> 03-03-01-10
# 비슷한 키워드로 엣지 추가: 03-03-01 -> 03-03-01-11
# 비슷한 키워드로 엣지 추가: 03-03-01-01 -> 03-03-01-02
# 비슷한 키워드로 엣지 추가: 03-03-01-01 -> 03-03-01-03
# 비슷한 키워드로 엣지 추가: 03-03-01-01 -> 03-03-01-04
# 비슷한 키워드로 엣지 추가: 03-03-01-01 -> 03-03-01-05
# 비슷한 키워드로 엣지 추가: 03-03-01-01 -> 03-03-01-06
# 비슷한 키워드로 엣지 추가: 03-03-01-01 -> 03-03-01-09
# 비슷한 키워드로 엣지 추가: 03-03-01-01 -> 03-03-01-10
# 비슷한 키워드로 엣지 추가: 03-03-01-01 -> 03-03-01-11
# 비슷한 키워드로 엣지 추가: 03-03-01-01 -> 03-03-02-01
# 비슷한 키워드로 엣지 추가: 03-03-01-01 -> 03-03-02-04
# 비슷한 키워드로 엣지 추가: 03-03-01-01 -> 03-03-03-01
# 비슷한 키워드로 엣지 추가: 03-03-01-01 -> 03-03-03-04
# 비슷한 키워드로 엣지 추가: 03-03-01-01 -> 03-03-03-05
# 비슷한 키워드로 엣지 추가: 03-03-01-01 -> 03-03-04-01
# 비슷한 키워드로 엣지 추가: 03-03-01-01 -> 03-03-06-01
# 비슷한 키워드로 엣지 추가: 03-03-01-01 -> 03-04-01-02
# 비슷한 키워드로 엣지 추가: 03-03-01-01 -> 03-04-02-01
# 비슷한 키워드로 엣지 추가: 03-03-01-01 -> 03-04-02-02
# 비슷한 키워드로 엣지 추가: 03-03-01-02 -> 03-03-01-04
# 비슷한 키워드로 엣지 추가: 03-03-01-02 -> 03-03-01-05
# 비슷한 키워드로 엣지 추가: 03-03-01-02 -> 03-03-01-06
# 비슷한 키워드로 엣지 추가: 03-03-01-02 -> 03-03-01-09
# 비슷한 키워드로 엣지 추가: 03-03-01-02 -> 03-03-01-10
# 비슷한 키워드로 엣지 추가: 03-03-01-02 -> 03-03-01-11
# 비슷한 키워드로 엣지 추가: 03-03-01-02 -> 03-03-02-02
# 비슷한 키워드로 엣지 추가: 03-03-01-02 -> 03-03-03-02
# 비슷한 키워드로 엣지 추가: 03-03-01-03 -> 03-03-01-11
# 비슷한 키워드로 엣지 추가: 03-03-01-03 -> 03-03-02-01
# 비슷한 키워드로 엣지 추가: 03-03-01-03 -> 03-03-02-04
# 비슷한 키워드로 엣지 추가: 03-03-01-03 -> 03-03-03-01
# 비슷한 키워드로 엣지 추가: 03-03-01-03 -> 03-03-03-04
# 비슷한 키워드로 엣지 추가: 03-03-01-03 -> 03-03-03-05
# 비슷한 키워드로 엣지 추가: 03-03-01-03 -> 03-03-04-01
# 비슷한 키워드로 엣지 추가: 03-03-01-03 -> 03-03-06-01
# 비슷한 키워드로 엣지 추가: 03-03-01-03 -> 03-04-02-01
# 비슷한 키워드로 엣지 추가: 03-03-01-03 -> 03-04-02-02
# 비슷한 키워드로 엣지 추가: 03-03-01-03 -> 03-04-02-03
# 비슷한 키워드로 엣지 추가: 03-03-01-04 -> 03-03-01-05
# 비슷한 키워드로 엣지 추가: 03-03-01-04 -> 03-03-01-06
# 비슷한 키워드로 엣지 추가: 03-03-01-04 -> 03-03-01-09
# 비슷한 키워드로 엣지 추가: 03-03-01-04 -> 03-03-01-10
# 비슷한 키워드로 엣지 추가: 03-03-01-04 -> 03-03-01-11
# 비슷한 키워드로 엣지 추가: 03-03-01-04 -> 03-03-02-03
# 비슷한 키워드로 엣지 추가: 03-03-01-04 -> 03-03-03-03
# 비슷한 키워드로 엣지 추가: 03-03-01-05 -> 03-03-01-06
# 비슷한 키워드로 엣지 추가: 03-03-01-05 -> 03-03-01-09
# 비슷한 키워드로 엣지 추가: 03-03-01-05 -> 03-03-01-10
# 비슷한 키워드로 엣지 추가: 03-03-01-05 -> 03-03-01-11
# 비슷한 키워드로 엣지 추가: 03-03-01-05 -> 03-03-02-05
# 비슷한 키워드로 엣지 추가: 03-03-01-05 -> 03-03-03-06
# 비슷한 키워드로 엣지 추가: 03-03-01-05 -> 03-04-02-04
# 비슷한 키워드로 엣지 추가: 03-03-01-06 -> 03-03-01-09
# 비슷한 키워드로 엣지 추가: 03-03-01-06 -> 03-03-01-10
# 비슷한 키워드로 엣지 추가: 03-03-01-06 -> 03-03-01-11
# 비슷한 키워드로 엣지 추가: 03-03-01-06 -> 03-03-02-06
# 비슷한 키워드로 엣지 추가: 03-03-01-06 -> 03-03-03-07
# 비슷한 키워드로 엣지 추가: 03-03-01-06 -> 03-04-02-05
# 비슷한 키워드로 엣지 추가: 03-03-01-09 -> 03-03-01-10
# 비슷한 키워드로 엣지 추가: 03-03-01-09 -> 03-03-01-11
# 비슷한 키워드로 엣지 추가: 03-03-01-09 -> 03-03-02-02
# 비슷한 키워드로 엣지 추가: 03-03-01-09 -> 03-03-03-02
# 비슷한 키워드로 엣지 추가: 03-03-01-10 -> 03-03-01-11
# 비슷한 키워드로 엣지 추가: 03-03-01-10 -> 03-03-02-03
# 비슷한 키워드로 엣지 추가: 03-03-01-10 -> 03-03-03-03
# 비슷한 키워드로 엣지 추가: 03-03-01-11 -> 03-03-02-01
# 비슷한 키워드로 엣지 추가: 03-03-01-11 -> 03-03-02-04
# 비슷한 키워드로 엣지 추가: 03-03-01-11 -> 03-03-03-01
# 비슷한 키워드로 엣지 추가: 03-03-01-11 -> 03-03-03-04
# 비슷한 키워드로 엣지 추가: 03-03-01-11 -> 03-03-03-05
# 비슷한 키워드로 엣지 추가: 03-03-01-11 -> 03-03-04-01
# 비슷한 키워드로 엣지 추가: 03-03-01-11 -> 03-03-06-01
# 비슷한 키워드로 엣지 추가: 03-03-01-11 -> 03-04-02-01
# 비슷한 키워드로 엣지 추가: 03-03-01-11 -> 03-04-02-02
# 비슷한 키워드로 엣지 추가: 03-03-01-11 -> 03-04-02-03
# 비슷한 키워드로 엣지 추가: 03-03-02-01 -> 03-03-02-04
# 비슷한 키워드로 엣지 추가: 03-03-02-01 -> 03-03-03-01
# 비슷한 키워드로 엣지 추가: 03-03-02-01 -> 03-03-03-04
# 비슷한 키워드로 엣지 추가: 03-03-02-01 -> 03-03-03-05
# 비슷한 키워드로 엣지 추가: 03-03-02-01 -> 03-03-04-01
# 비슷한 키워드로 엣지 추가: 03-03-02-01 -> 03-03-06-01
# 비슷한 키워드로 엣지 추가: 03-03-02-01 -> 03-04-01-02
# 비슷한 키워드로 엣지 추가: 03-03-02-01 -> 03-04-02-01
# 비슷한 키워드로 엣지 추가: 03-03-02-01 -> 03-04-02-02
# 비슷한 키워드로 엣지 추가: 03-03-02-02 -> 03-03-03-02
# 비슷한 키워드로 엣지 추가: 03-03-02-03 -> 03-03-03-03
# 비슷한 키워드로 엣지 추가: 03-03-02-04 -> 03-03-03-01
# 비슷한 키워드로 엣지 추가: 03-03-02-04 -> 03-03-03-04
# 비슷한 키워드로 엣지 추가: 03-03-02-04 -> 03-03-03-05
# 비슷한 키워드로 엣지 추가: 03-03-02-04 -> 03-03-04-01
# 비슷한 키워드로 엣지 추가: 03-03-02-04 -> 03-03-06-01
# 비슷한 키워드로 엣지 추가: 03-03-02-04 -> 03-04-02-01
# 비슷한 키워드로 엣지 추가: 03-03-02-04 -> 03-04-02-02
# 비슷한 키워드로 엣지 추가: 03-03-02-04 -> 03-04-02-03
# 비슷한 키워드로 엣지 추가: 03-03-02-05 -> 03-03-03-06
# 비슷한 키워드로 엣지 추가: 03-03-02-05 -> 03-04-02-04
# 비슷한 키워드로 엣지 추가: 03-03-02-06 -> 03-03-03-07
# 비슷한 키워드로 엣지 추가: 03-03-02-06 -> 03-04-02-05
# 비슷한 키워드로 엣지 추가: 03-03-03 -> 03-03-03-01
# 비슷한 키워드로 엣지 추가: 03-03-03 -> 03-03-03-02
# 비슷한 키워드로 엣지 추가: 03-03-03 -> 03-03-03-03
# 비슷한 키워드로 엣지 추가: 03-03-03 -> 03-03-03-06
# 비슷한 키워드로 엣지 추가: 03-03-03 -> 03-03-03-07
# 비슷한 키워드로 엣지 추가: 03-03-03-01 -> 03-03-03-02
# 비슷한 키워드로 엣지 추가: 03-03-03-01 -> 03-03-03-03
# 비슷한 키워드로 엣지 추가: 03-03-03-01 -> 03-03-03-04
# 비슷한 키워드로 엣지 추가: 03-03-03-01 -> 03-03-03-05
# 비슷한 키워드로 엣지 추가: 03-03-03-01 -> 03-03-03-06
# 비슷한 키워드로 엣지 추가: 03-03-03-01 -> 03-03-03-07
# 비슷한 키워드로 엣지 추가: 03-03-03-01 -> 03-03-04-01
# 비슷한 키워드로 엣지 추가: 03-03-03-01 -> 03-03-06-01
# 비슷한 키워드로 엣지 추가: 03-03-03-01 -> 03-04-01-02
# 비슷한 키워드로 엣지 추가: 03-03-03-01 -> 03-04-02-01
# 비슷한 키워드로 엣지 추가: 03-03-03-01 -> 03-04-02-02
# 비슷한 키워드로 엣지 추가: 03-03-03-02 -> 03-03-03-03
# 비슷한 키워드로 엣지 추가: 03-03-03-02 -> 03-03-03-06
# 비슷한 키워드로 엣지 추가: 03-03-03-02 -> 03-03-03-07
# 비슷한 키워드로 엣지 추가: 03-03-03-03 -> 03-03-03-06
# 비슷한 키워드로 엣지 추가: 03-03-03-03 -> 03-03-03-07
# 비슷한 키워드로 엣지 추가: 03-03-03-04 -> 03-03-03-05
# 비슷한 키워드로 엣지 추가: 03-03-03-04 -> 03-03-04-01
# 비슷한 키워드로 엣지 추가: 03-03-03-04 -> 03-03-06-01
# 비슷한 키워드로 엣지 추가: 03-03-03-04 -> 03-04-02-01
# 비슷한 키워드로 엣지 추가: 03-03-03-04 -> 03-04-02-02
# 비슷한 키워드로 엣지 추가: 03-03-03-04 -> 03-04-02-03
# 비슷한 키워드로 엣지 추가: 03-03-03-05 -> 03-03-04-01
# 비슷한 키워드로 엣지 추가: 03-03-03-05 -> 03-03-06-01
# 비슷한 키워드로 엣지 추가: 03-03-03-05 -> 03-04-02-01
# 비슷한 키워드로 엣지 추가: 03-03-03-05 -> 03-04-02-02
# 비슷한 키워드로 엣지 추가: 03-03-03-05 -> 03-04-02-03
# 비슷한 키워드로 엣지 추가: 03-03-03-06 -> 03-03-03-07
# 비슷한 키워드로 엣지 추가: 03-03-03-06 -> 03-04-02-04
# 비슷한 키워드로 엣지 추가: 03-03-03-07 -> 03-04-02-05
# 비슷한 키워드로 엣지 추가: 03-03-04 -> 03-03-04-01
# 비슷한 키워드로 엣지 추가: 03-03-04-01 -> 03-03-06-01
# 비슷한 키워드로 엣지 추가: 03-03-04-01 -> 03-04-01-02
# 비슷한 키워드로 엣지 추가: 03-03-04-01 -> 03-04-02-01
# 비슷한 키워드로 엣지 추가: 03-03-04-01 -> 03-04-02-02
# 비슷한 키워드로 엣지 추가: 03-03-06 -> 03-03-06-01
# 비슷한 키워드로 엣지 추가: 03-03-06-01 -> 03-04-01-02
# 비슷한 키워드로 엣지 추가: 03-03-06-01 -> 03-04-02-01
# 비슷한 키워드로 엣지 추가: 03-03-06-01 -> 03-04-02-02
# 비슷한 키워드로 엣지 추가: 03-04 -> 03-04-01
# 비슷한 키워드로 엣지 추가: 03-04 -> 03-04-01-02
# 비슷한 키워드로 엣지 추가: 03-04 -> 03-04-02
# 비슷한 키워드로 엣지 추가: 03-04 -> 03-04-02-01
# 비슷한 키워드로 엣지 추가: 03-04 -> 03-04-02-04
# 비슷한 키워드로 엣지 추가: 03-04 -> 03-04-02-05
# 비슷한 키워드로 엣지 추가: 03-04-01 -> 03-04-01-02
# 비슷한 키워드로 엣지 추가: 03-04-02 -> 03-04-02-01
# 비슷한 키워드로 엣지 추가: 03-04-02 -> 03-04-02-04
# 비슷한 키워드로 엣지 추가: 03-04-02 -> 03-04-02-05
# 비슷한 키워드로 엣지 추가: 03-04-02-01 -> 03-04-02-02
# 비슷한 키워드로 엣지 추가: 03-04-02-01 -> 03-04-02-03
# 비슷한 키워드로 엣지 추가: 03-04-02-01 -> 03-04-02-04
# 비슷한 키워드로 엣지 추가: 03-04-02-01 -> 03-04-02-05
# 비슷한 키워드로 엣지 추가: 03-04-02-02 -> 03-04-02-03
# 비슷한 키워드로 엣지 추가: 03-04-02-04 -> 03-04-02-05
# 그래프 시각화 완료
