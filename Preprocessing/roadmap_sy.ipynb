# %%
# !pip install graphviz

# %%
from graphviz import Digraph

# 다이어그램 생성
dot = Digraph(comment='초등 수학 - 도형과 측정', format='png', engine='dot')

# %%
# 노드 추가
# 3. 도형과 측정
dot.node('03', '도형과 측정')  # 대분류

# 입체도형
dot.node('03-01', '입체도형')  # 중분류

dot.node('03-01-02', '직육면체의 모양')

# 직육면체와 정육면체
dot.node('03-01-02-01', '직육면체')
dot.node('03-01-02-02', '직육면체의 구성요소와 성질')
dot.node('03-01-02-03', '정육면체')
dot.node('03-01-02-04', '정육면체의 구성요소와 성질')
dot.node('03-01-02-05', '직육면체의 겨냥도')
dot.node('03-01-02-06', '직육면체의 전개도')
dot.node('03-01-02-07', '정육면체의 겨냥도')
dot.node('03-01-02-08', '정육면체의 전개도')
dot.node('03-01-02-09', '직육면체 겉넓이 구하기')
dot.node('03-01-02-10', '정육면체 겉넓이 구하기')
dot.node('03-01-02-11', '직육면체의 부피 구하기')
dot.node('03-01-02-12', '정육면체의 부피 구하기')

dot.node('03-01-03', '원기둥의 모양')

# 원기둥, 원뿔
dot.node('03-01-03-01', '원기둥')
dot.node('03-01-03-02', '원뿔')
dot.node('03-01-03-03', '원기둥의 구성요소와 성질')
dot.node('03-01-03-04', '원뿔의 구성요소와 성질')
dot.node('03-01-03-05', '원기둥 전개도')

dot.node('03-01-04', '구의 모양')

# 구
dot.node('03-01-04-01', '구 이해하기')
dot.node('03-01-04-02', '구의 구성요소와 성질')

dot.node('03-01-05', '여러 모양으로 쌓기')
dot.node('03-01-05-01', '모양에 대해 위치나 방향을 이용하여 말하기')

# 입체도형의 공간 감각
dot.node('03-01-05-02', '입체도형의 쌓기나무 개수 구하기')
dot.node('03-01-05-03', '입체도형의 위. 앞. 옆에서 본 모양 표현하기')
dot.node('03-01-05-04', '입체도형의 모양 추론하기')


# 각기둥과 각뿔
dot.node('03-01-07', '각기둥')
dot.node('03-01-08', '각뿔')
dot.node('03-01-07-01', '각기둥 이해하기')
dot.node('03-01-07-02', '각기둥의 구성요소와 성질')
dot.node('03-01-08-01', '각뿔 이해하기')
dot.node('03-01-08-02', '각뿔의 구성요소와 성질')

# 평면도형
dot.node('03-02', '평면도형')

dot.node('03-02-02', '삼각형')

# 삼각형
dot.node('03-02-02-01', '여러 가지 삼각형 분류하기')
dot.node('03-02-02-02', '이등변삼각형')
dot.node('03-02-02-03', '정삼각형')
dot.node('03-02-02-04', '직각삼각형')
dot.node('03-02-02-05', '예각삼각형')
dot.node('03-02-02-06', '둔각삼각형')

dot.node('03-02-03', '사각형')

# 사각형
dot.node('03-02-03-01', '여러 가지 사각형 분류하기')
dot.node('03-02-03-02', '직사각형')
dot.node('03-02-03-03', '정사각형')
dot.node('03-02-03-04', '사다리꼴')
dot.node('03-02-03-05', '평행사변형')
dot.node('03-02-03-06', '마름모')

dot.node('03-02-04', '원')

# 원
dot.node('03-02-04-01', '원의 중심')
dot.node('03-02-04-02', '원의 반지름')
dot.node('03-02-04-03', '원의 지름')
dot.node('03-02-04-04', '원의 성질')
dot.node('03-02-04-05', '컴퍼스를 이용해 원 그리기')
dot.node('03-02-04-06', '원주와 지름 측정하기')
dot.node('03-02-04-07', '원주율 이해하기')
dot.node('03-02-04-08', '원주 구하기')
dot.node('03-02-04-09', '원의 넓이 구하기')


dot.node('03-02-05', '직선, 선분, 반직선')

# 각
dot.node('03-02-06', '각')

dot.node('03-02-06-01', '직각')
dot.node('03-02-06-02', '예각')
dot.node('03-02-06-03', '둔각')
dot.node('03-02-06-04', '직선의 수직관계')
dot.node('03-02-06-05', '직선의 평행관계')
dot.node('03-02-06-06', '각의 단위 이해하기')
dot.node('03-02-06-07', '각의 크기 측정하기')
dot.node('03-02-06-08', '각의 크기 어림하기')
dot.node('03-02-06-09', '삼각형의 내각의 크기의 합 추론하기')
dot.node('03-02-06-10', '사각형의 내각의 크기의 합 추론하기')

# 평면도형의 이동
dot.node('03-02-07', '평명도형의 이동')

dot.node('03-02-07-01', '도형 밀기, 뒤집기, 돌리기')
dot.node('03-02-07-02', '평면에서의 점의 이동')

# 합동과 대칭
dot.node('03-02-07-03', '도형의 합동 이해하기')
dot.node('03-02-07-04', '합동인 도형의 성질')
dot.node('03-02-07-05', '선대칭도형')
dot.node('03-02-07-06', '점대칭도형')

# 다각형
dot.node('03-02-08', '다각형과 정다각형')

dot.node('03-02-08-01', '다각형')
dot.node('03-02-08-02', '정다각형')
dot.node('03-02-08-03', '주어진 도형으로 여러 가지 모양 만들거나 채우기')

# 다각형의 둘레와 넓이
dot.node('03-02-08-04', '평면도형의 둘레')
dot.node('03-02-08-05', '직사각형의 넓이')
dot.node('03-02-08-06', '정사각형의 넓이')
dot.node('03-02-08-07', '사다리꼴의 넓이')
dot.node('03-02-08-08', '평행사변형의 넓이')
dot.node('03-02-08-09', '마름모의 넓이')

# 양의 비교
dot.node('03-03', '양의 비교')

# 길이
dot.node('03-03-01', '길이')

dot.node('03-03-01-01', '길이 단위 이해하기')
dot.node('03-03-01-02', '길이 측정하기')
dot.node('03-03-01-03', '1m와 1cm의 관계 이해하기')
dot.node('03-03-01-04', '물건의 길이 어림하기')
dot.node('03-03-01-05', '길이의 덧셈')
dot.node('03-03-01-06', '길이의 뺄셈')
dot.node('03-03-01-07', '1mm')
dot.node('03-03-01-08', '1km')
dot.node('03-03-01-09', '길이 측정하기')
dot.node('03-03-01-10', '길이 어림하기')
dot.node('03-03-01-11', '길이의 관계 이해하기')

# 들이
dot.node('03-03-02', '들이')

dot.node('03-03-02-01', '들이 단위 이해하기')
dot.node('03-03-02-02', '들이 측정하기')
dot.node('03-03-02-03', '들이 어림하기')
dot.node('03-03-02-04', '1L와 1mL의 관계 이해하기')
dot.node('03-03-02-05', '들이의 덧셈')
dot.node('03-03-02-06', '들이의 뺄셈')

# 무게
dot.node('03-03-03', '무게')

dot.node('03-03-03-01', '무계 단위 이해하기')
dot.node('03-03-03-02', '무게 측정하기')
dot.node('03-03-03-03', '무게 어림하기')
dot.node('03-03-03-04', '1kg와 1g의 관계 이해하기')
dot.node('03-03-03-04', '1kg와 1t의 관계 이해하기')
dot.node('03-03-03-05', '무게의 덧셈')
dot.node('03-03-03-06', '무게의 뺄셈')

# 넓이
dot.node('03-03-04', '넓이')
dot.node('03-03-04-01', '넓이 단위 이해하기')

# 부피
dot.node('03-03-06', '부피')
dot.node('03-03-06-01', '부피 단위 이해하기')

# 시각과 시간
dot.node('03-04', '시각과 시간')

# 시각
dot.node('03-04-01', '시각')

dot.node('03-04-01-01', '시계 읽기')
dot.node('03-04-01-02', '초 단위까지 시각 읽기')

# 시간
dot.node('03-04-02', '시간')

dot.node('03-04-02-01', '시간과 분의 관계 이해하기')
dot.node('03-04-02-02', '1분, 1시간, 1일, 1주일, 1개월, 1년 사이의 관계 이해하기')
dot.node('03-04-02-03', '1분과 1초의 관계')
dot.node('03-04-02-04', '시간의 덧셈')
dot.node('03-04-02-05', '시간의 뺄셈')

# %%
# 엣지 추가
# 도형과 측정 -> 입체도형
dot.edge('03', '03-01')

# 입체도형 -> 직육면체의 모양
dot.edge('03-01', '03-01-02')

# 직육면체의 모양 -> 하위분류들
dot.edge('03-01-02', '03-01-02-01')
dot.edge('03-01-02', '03-01-02-02')
dot.edge('03-01-02', '03-01-02-03')
dot.edge('03-01-02', '03-01-02-04')
dot.edge('03-01-02', '03-01-02-05')
dot.edge('03-01-02', '03-01-02-06')
dot.edge('03-01-02', '03-01-02-07')
dot.edge('03-01-02', '03-01-02-08')
dot.edge('03-01-02', '03-01-02-09')
dot.edge('03-01-02', '03-01-02-10')
dot.edge('03-01-02', '03-01-02-11')
dot.edge('03-01-02', '03-01-02-12')

# 입체도형 -> 원기둥의 모양
dot.edge('03-01', '03-01-03')

# 원기둥의 모양 -> 하위분류들
dot.edge('03-01-03', '03-01-03-01')
dot.edge('03-01-03', '03-01-03-02')
dot.edge('03-01-03', '03-01-03-03')
dot.edge('03-01-03', '03-01-03-04')
dot.edge('03-01-03', '03-01-03-05')

# 입체도형 -> 구의 모양
dot.edge('03-01', '03-01-04')

# 구의 모양 -> 하위분류들
dot.edge('03-01-04', '03-01-04-01')
dot.edge('03-01-04', '03-01-04-02')

# 입체도형 -> 여러 모양으로 쌓기
dot.edge('03-01', '03-01-05')

# 여러 모양으로 쌓기 -> 하위분류들
dot.edge('03-01-05', '03-01-05-01')
dot.edge('03-01-05', '03-01-05-02')
dot.edge('03-01-05', '03-01-05-03')
dot.edge('03-01-05', '03-01-05-04')

# 입체도형 -> 각기둥
dot.edge('03-01', '03-01-07')

# 각기둥 -> 하위분류들
dot.edge('03-01-07', '03-01-07-01')
dot.edge('03-01-07', '03-01-07-02')

# 각뿔
dot.edge('03-01', '03-01-08')
dot.edge('03-01-08', '03-01-08-01')
dot.edge('03-01-08', '03-01-08-02')

# 도형과 측정 -> 평면도형
dot.edge('03', '03-02')

# 평면도형 -> 하위분류들
dot.edge('03-02', '03-02-05')

# 선분 -> 다각형
dot.edge('03-02-05', '03-02-06')
dot.edge('03-02-05', '03-02-04')
dot.edge('03-02-05', '03-02-02')
dot.edge('03-02-05', '03-02-03')
dot.edge('03-02-05', '03-02-08')

# 평면도형 -> 각
dot.edge('03-02', '03-02-06')

# 각 -> 하위분류들
dot.edge('03-02-06', '03-02-06-01')
dot.edge('03-02-06', '03-02-06-02')
dot.edge('03-02-06', '03-02-06-03')
dot.edge('03-02-06', '03-02-06-04')
dot.edge('03-02-06', '03-02-06-05')
dot.edge('03-02-06', '03-02-06-06')
dot.edge('03-02-06', '03-02-06-07')
dot.edge('03-02-06', '03-02-06-08')
dot.edge('03-02-06', '03-02-06-09')
dot.edge('03-02-06', '03-02-06-10')

# 평면도형 -> 평면도형의 이동
dot.edge('03-02', '03-02-07')

# 평면도형의 이동 -> 하위분류들
dot.edge('03-02-07', '03-02-07-01')
dot.edge('03-02-07', '03-02-07-02')
dot.edge('03-02-07', '03-02-07-03')
dot.edge('03-02-07', '03-02-07-04')
dot.edge('03-02-07', '03-02-07-05')
dot.edge('03-02-07', '03-02-07-06')

# 평면도형 -> 원
dot.edge('03-02', '03-02-04')

# 원 -> 하위분류들
dot.edge('03-02-04', '03-02-04-01')
dot.edge('03-02-04', '03-02-04-02')
dot.edge('03-02-04', '03-02-04-03')
dot.edge('03-02-04', '03-02-04-04')
dot.edge('03-02-04', '03-02-04-05')
dot.edge('03-02-04', '03-02-04-06')
dot.edge('03-02-04', '03-02-04-07')
dot.edge('03-02-04', '03-02-04-08')
dot.edge('03-02-04', '03-02-04-09')

# 평면도형 -> 삼각형
dot.edge('03-02', '03-02-02')

# 삼각형 -> 하위분류들
dot.edge('03-02-02', '03-02-02-01')
dot.edge('03-02-02', '03-02-02-02')
dot.edge('03-02-02', '03-02-02-03')
dot.edge('03-02-02', '03-02-02-04')
dot.edge('03-02-02', '03-02-02-05')
dot.edge('03-02-02', '03-02-02-06')


# 평면도형 -> 사각형
dot.edge('03-02', '03-02-03')

# 사각형 -> 하위분류들
dot.edge('03-02-03', '03-02-03-01')
dot.edge('03-02-03', '03-02-03-02')
dot.edge('03-02-03', '03-02-03-03')
dot.edge('03-02-03', '03-02-03-04')
dot.edge('03-02-03', '03-02-03-05')
dot.edge('03-02-03', '03-02-03-06')

# 평면도형 -> 다각형과 정다각형
dot.edge('03-02', '03-02-08')

# 다각형과 정다각형 -> 하위분류들
dot.edge('03-02-08', '03-02-08-01')
dot.edge('03-02-08', '03-02-08-02')
dot.edge('03-02-08', '03-02-08-03')
dot.edge('03-02-08', '03-02-08-04')
dot.edge('03-02-08', '03-02-08-05')
dot.edge('03-02-08', '03-02-08-06')
dot.edge('03-02-08', '03-02-08-07')
dot.edge('03-02-08', '03-02-08-08')
dot.edge('03-02-08', '03-02-08-09')

# 각 다각형과 넓이 연결
dot.edge('03-02-03-02', '03-02-08-05')
dot.edge('03-02-03-03', '03-02-08-06')
dot.edge('03-02-03-04', '03-02-08-07')
dot.edge('03-02-03-05', '03-02-08-08')
dot.edge('03-02-03-06', '03-02-08-09')

# 길이 -> 둘레
dot.edge('03-03', '03-02-08-04')

# 도형과 측정 -> 양의 비교
dot.edge('03', '03-03')

# 양의 비교 -> 길이
dot.edge('03-03', '03-03-01')

# 길이 -> 하위분류들
dot.edge('03-03-01', '03-03-01-01')
dot.edge('03-03-01', '03-03-01-02')
dot.edge('03-03-01', '03-03-01-03')
dot.edge('03-03-01', '03-03-01-04')
dot.edge('03-03-01', '03-03-01-05')
dot.edge('03-03-01', '03-03-01-06')
dot.edge('03-03-01', '03-03-01-07')
dot.edge('03-03-01', '03-03-01-08')
dot.edge('03-03-01', '03-03-01-09')
dot.edge('03-03-01', '03-03-01-10')
dot.edge('03-03-01', '03-03-01-11')

# 양의 비교 -> 들이
dot.edge('03-03', '03-03-02')

# 들이 -> 하위분류들
dot.edge('03-03-02', '03-03-02-01')
dot.edge('03-03-02', '03-03-02-02')
dot.edge('03-03-02', '03-03-02-03')
dot.edge('03-03-02', '03-03-02-04')
dot.edge('03-03-02', '03-03-02-05')
dot.edge('03-03-02', '03-03-02-06')

# 양의 비교 -> 무게
dot.edge('03-03', '03-03-03')

# 무게 -> 하위분류들
dot.edge('03-03-03', '03-03-03-01')
dot.edge('03-03-03', '03-03-03-02')
dot.edge('03-03-03', '03-03-03-03')
dot.edge('03-03-03', '03-03-03-04')
dot.edge('03-03-03', '03-03-03-05')
dot.edge('03-03-03', '03-03-03-06')

# 양의 비교 -> 넓이
dot.edge('03-03', '03-03-04')

# 넓이 -> 하위분류
dot.edge('03-03-04', '03-03-04-01')
dot.edge('03-03-04', '03-02-08-05')
dot.edge('03-03-04', '03-02-08-06')
dot.edge('03-03-04', '03-02-08-07')
dot.edge('03-03-04', '03-02-08-08')
dot.edge('03-03-04', '03-02-08-09')

# 양의 비교 -> 부피
dot.edge('03-03', '03-03-06')

# 부피 -> 하위분류
dot.edge('03-03-06', '03-03-06-01')
dot.edge('03-03-06', '03-02-06-02')

dot.edge('03-03-06', '03-01-02-11')
dot.edge('03-03-06', '03-01-02-12')

# 도형과 측정 -> 시각과 시간
dot.edge('03', '03-04')

# 시각과 시간 -> 하위분류들
dot.edge('03-04', '03-04-01')
dot.edge('03-04', '03-04-02')

# 시각 -> 하위분류들
dot.edge('03-04-01', '03-04-01-01')
dot.edge('03-04-01', '03-04-01-02')

# 시간 -> 하위분류들
dot.edge('03-04-02', '03-04-02-01')
dot.edge('03-04-02', '03-04-02-02')
dot.edge('03-04-02', '03-04-02-03')
dot.edge('03-04-02', '03-04-02-04')
dot.edge('03-04-02', '03-04-02-05')

# %%
# 글꼴 설정 (맑은 고딕 등 한글 지원 글꼴 지정)
dot.graph_attr.update({
    'fontname': 'Malgun Gothic'  # Windows: 맑은 고딕
})

dot.node_attr.update({
    'fontname': 'Malgun Gothic'
})

# 글꼴 설정 (맑은 고딕 등 한글 지원 글꼴 지정)
dot.edge_attr.update({
    'fontname': 'Malgun Gothic'  # Windows: 맑은 고딕
})

# 그래프 방향 설정 (왼쪽에서 오른쪽으로)
dot.attr(rankdir='LR')

# 다이어그램 생성
dot.render('math_curriculum_diagram_sm', view=True)
# Out:
# 'math_curriculum_diagram_sm.png'
