# %%
# !pip install graphviz

# %%
from graphviz import Digraph

# 다이어그램 생성
dot = Digraph(comment='초등 수학 - 수와연산', format='png', engine='dot')

# %%
# 대분류
dot.node('01', '수와 연산')  # 대분류

dot.node('01-01', '네 자리 이하의 수')  # 중분류
dot.node('01-01-01', '수')
dot.node('01-01-01-01', '수의 필요성 인식')
dot.node('01-01-01-02', '9 이하의 수')
dot.node('01-01-01-03', '99 이하의 수')
dot.node('01-01-01-04', '100 이상의 수')

dot.node('01-01-02', '수의 자리값과 위치적 기수법')
dot.node('01-01-02-01', '일, 십, 백, 천의 자리')
dot.node('01-01-02-02', '자리값의 합')
dot.node('01-01-02-03', '네 자리 이하의 수 읽기와 쓰기')

dot.node('01-01-03', '수의 계열과 크기 비교')
dot.node('01-01-03-01', '수의 계열 이해')
dot.node('01-01-03-02', '수의 크기 비교')
dot.node('01-01-03-03', '다양한 방법으로 수 세기')

dot.node('01-01-04', '수 감각 기르기')
dot.node('01-01-04-01', '하나의 수 분해하기')
dot.node('01-01-04-02', '두 수를 하나로 합성하기')

dot.node('01-02', '두 자리 수 범위의 덧셈과 뺄셈')  # 중분류
dot.node('01-02-01', '두 자리 수의 덧셈과 뺄셈의 의미')
dot.node('01-02-01-01', '덧셈이 이루어지는 실생활 상황과 연결')
dot.node('01-02-01-02', '뺄셈이 이루어지는 실생활 상황과 연결')
dot.node('01-02-01-03', '덧셈의 의미 이해')
dot.node('01-02-01-04', '뺄셈의 의미 이해')

dot.node('01-02-02', '두 자리 수의 덧셈과 뺄셈의 계산')
dot.node('01-02-02-01', '덧셈의 계산 원리 이해')
dot.node('01-02-02-02', '덧셈의 계산')
dot.node('01-02-02-03', '뺄셈의 계산 원리 이해')
dot.node('01-02-02-04', '뺄셈의 계산')


dot.node('01-02-03', '덧셈과 뺄셈의 관계')
dot.node('01-02-03-01', '덧셈식과 뺄셈식으로 표현')
dot.node('01-02-03-02', '덧셈식과 뺄셈식의 관계')


dot.node('01-02-04', '세 수의 덧셈과 뺄셈')
dot.node('01-02-04-01', '두 자리의 수의 범위에서 세 수의 덧셈')
dot.node('01-02-04-02', '두 자리의 수의 범위에서 세 수의 뺄셈')


dot.node('01-02-05', '□가 사용된 덧셈식과 뺄셈식')
dot.node('01-02-05-01', '실생활 상황을 □가 사용된 덧셈식으로 표현')
dot.node('01-02-05-02', '실생활 상황을 □가 사용된 뺄셈식으로 표현')
dot.node('01-02-05-03', '□값 구하기')



dot.node('01-03', '한 자리 수의 곱셈')  # 중분류
dot.node('01-03-01', '곱셈의 의미')
dot.node('01-03-01-01', '곱셈이 이루어지는 실생활 상황 이해')
dot.node('01-03-01-02', '실생활 상황을 곱셈식으로 나타내기')
dot.node('01-03-02', '곱셈구구와 한 자리 수 곱셈')
dot.node('01-03-02-01', '곱셈구구의 이해')
dot.node('01-03-02-02', '한 자리 수 곱셈의 계산')
dot.node('01-03-02-03', '곱셈구구의 표현과 유창한 사용')

# %%
# 대분류
dot.node('01', '수와 연산')  # 대분류


# 중분류: 수
dot.node('01-01', '수')  # 중분류

# 네 자리 이하의 수
dot.node('01-01-01', '네 자리 이하의 수')  # 소분류
dot.node('01-01-01-01', '수의 필요성 인식')

dot.node('01-01-01-02', '9 이하의 수')
dot.node('01-01-01-03', '99 이하의 수')
dot.node('01-01-01-04', '100 이상의 수')

dot.node('01-01-02', '수의 자리값과 위치적 기수법')
dot.node('01-01-02-01', '일, 십, 백, 천의 자리')
dot.node('01-01-02-02', '자리값의 합')
dot.node('01-01-02-03', '네 자리 이하의 수 읽기와 쓰기')

dot.node('01-01-03', '수의 계열과 크기 비교')
dot.node('01-01-03-01', '수의 계열 이해')
dot.node('01-01-03-02', '수의 크기 비교')
dot.node('01-01-03-03', '다양한 방법으로 수 세기')

dot.node('01-01-04', '수 감각 기르기')
dot.node('01-01-04-01', '하나의 수 분해하기')
dot.node('01-01-04-02', '두 수를 하나로 합성하기')

dot.node('01-01-05', '다섯 자리 이상의 수')  # 소분류
dot.node('01-01-05-01', '큰 수의 필요성 인식')
dot.node('01-01-05-02', '큰 수의 자리값 이해')
dot.node('01-01-05-03', '큰 수 읽기와 쓰기')
dot.node('01-01-05-04', '수의 계열 이해')
dot.node('01-01-05-05', '수의 크기 비교')


# 덧셈
dot.node('01-02', '덧셈')  # 중분류
dot.node('01-02-01', '덧셈의 의미')
dot.node('01-02-01-01', '덧셈이 이루어지는 실생활 상황과 연결')
dot.node('01-02-01-02', '덧셈의 의미 이해')

dot.node('01-02-02', '두 자리 수의 덧셈')
dot.node('01-02-02-01', '덧셈의 계산 원리 이해')
dot.node('01-02-02-02', '덧셈의 계산')

dot.node('01-02-03', '세 자리 수의 덧셈')
dot.node('01-02-03-01', '세 자리 수의 계산')
dot.node('01-02-03-02', '받아올림이 있는 덧셈의 이해')

dot.node('01-02-04', '세 수의 덧셈')
dot.node('01-02-04-01', '세 수의 계산 이해')

dot.node('01-02-05', '□가 사용된 덧셈식')
dot.node('01-02-05-01', '실생활 상황을 □가 사용된 덧셈식으로 표현')
dot.node('01-02-05-02', '□값 구하기')

# 뺄셈
dot.node('01-03', '뺄셈')  # 중분류
dot.node('01-03-01', '뺄셈의 의미')
dot.node('01-03-01-01', '뺄셈이 이루어지는 실생활 상황과 연결')
dot.node('01-03-01-02', '뺄셈의 의미 이해')

dot.node('01-03-02', '두 자리 수의 뺄셈')
dot.node('01-03-02-01', '뺄셈의 계산 원리 이해')
dot.node('01-03-02-02', '뺄셈의 계산')

dot.node('01-03-03', '세 자리 수의 뺄셈')
dot.node('01-03-03-01', '세 자리 수의 계산')
dot.node('01-03-03-02', '받아내림이 있는 뺄셈의 이해')

dot.node('01-03-04', '□가 사용된 뺄셈식')
dot.node('01-03-04-01', '실생활 상황을 □가 사용된 뺄셈식으로 표현')
dot.node('01-03-04-02', '□값 구하기')

# 곱셈
dot.node('01-04', '곱셈')  # 중분류
dot.node('01-04-01', '곱셈의 의미')
dot.node('01-04-01-01', '곱셈이 이루어지는 실생활 상황 이해')
dot.node('01-04-01-02', '실생활 상황을 곱셈식으로 나타내기')

dot.node('01-04-02', '곱셈의 계산')
dot.node('01-04-02-01', '두 자리 수 * 한 자리 수')
dot.node('01-04-02-02', '세 자리 수 * 한 자리 수')
dot.node('01-04-02-03', '두 자리 수 * 두 자리 수')

# 나눗셈
dot.node('01-05', '나눗셈')  # 중분류
dot.node('01-05-01', '나눗셈의 의미')
dot.node('01-05-01-01', '실생활 속 나눗셈 상황')
dot.node('01-05-01-02', '곱셈과 나눗셈의 관계')
dot.node('01-05-02', '나눗셈의 계산')
dot.node('01-05-02-01', '나누는 수가 한 자리 수인 나눗셈')
dot.node('01-05-02-02', '나누는 수가 두 자리 수인 나눗셈')

dot.node('01-05-03', '몫과 나머지')
dot.node('01-05-03-01', '몫과 나머지의 의미')
dot.node('01-05-03-02', '몫과 나머지를 활용한 문제 해결')

dot.node('01-05-04', '나눗셈의 활용')
dot.node('01-05-04-01', '실생활에서 나눗셈 활용')
dot.node('01-05-04-02', '나눗셈 결과를 검산과 확인')



# 자연수의 어림셈
dot.node('01-07', '자연수의 어림셈')  # 중분류

# 덧셈에서 어림셈
dot.node('01-07-01', '덧셈에서 어림셈')
dot.node('01-07-01-01', '덧셈 결과 어림의 필요성')
dot.node('01-07-01-02', '덧셈 어림의 기본 방법')
dot.node('01-07-01-03', '덧셈 어림의 검증')

# 뺄셈에서 어림셈
dot.node('01-07-02', '뺄셈에서 어림셈')
dot.node('01-07-02-01', '뺄셈 결과 어림의 필요성')
dot.node('01-07-02-02', '뺄셈 어림의 기본 방법')
dot.node('01-07-02-03', '뺄셈 어림의 검증')

# 곱셈에서 어림셈
dot.node('01-07-03', '곱셈에서 어림셈')
dot.node('01-07-03-01', '곱셈 결과 어림의 필요성')
dot.node('01-07-03-02', '곱셈 어림의 기본 방법')
dot.node('01-07-03-03', '곱셈 어림의 검증')

# 나눗셈에서 어림셈
dot.node('01-07-04', '나눗셈에서 어림셈')
dot.node('01-07-04-01', '나눗셈 결과 어림의 필요성')
dot.node('01-07-04-02', '나눗셈 어림의 기본 방법')
dot.node('01-07-04-03', '나눗셈 어림의 검증')


# 분수
dot.node('01-08', '분수')  # 중분류
dot.node('01-08-01', '분수의 개념 이해')
dot.node('01-08-01-01', '양의 등분할과 분수의 필요성')
dot.node('01-08-01-02', '분모와 분자의 의미')

dot.node('01-08-02', '분수의 종류와 관계')
dot.node('01-08-02-01', '단위분수, 진분수, 가분수, 대분수')
dot.node('01-08-02-02', '가분수와 대분수의 변환')

dot.node('01-08-03', '분수의 크기 비교')
dot.node('01-08-03-01', '분모가 같은 분수의 크기 비교')
dot.node('01-08-03-02', '단위분수끼리의 크기 비교')

dot.node('01-08-04', '분수의 덧셈과 뺄셈')
dot.node('01-08-04-01', '분모가 같은 분수의 덧셈')
dot.node('01-08-04-02', '분모가 같은 분수의 뺄셈')
dot.node('01-08-04-03', '계산 원리 이해')
dot.node('01-08-04-04', '실생활 문제에서 분수 계산 활용')

dot.node('01-08-05', '분수의 곱셈과 나눗셈')
dot.node('01-08-05-01', '분수의 곱셈의 계산 원리 탐구')
dot.node('01-08-05-02', '분수의 나눗셈의 계산 원리 탐구')

# 소수
dot.node('01-09', '소수')  # 중분류
dot.node('01-09-01', '소수의 개념 이해')
dot.node('01-09-01-01', '분모가 10인 진분수와 소수의 관계')
dot.node('01-09-01-02', '소수 한 자리 수 읽기와 쓰기')

dot.node('01-09-02', '소수의 자릿값과 계산')
dot.node('01-09-02-01', '소수 두 자리 수와 세 자리 수의 자릿값 이해')
dot.node('01-09-02-02', '소수의 덧셈과 뺄셈 원리')

dot.node('01-09-03', '소수의 크기 비교')
dot.node('01-09-03-01', '소수의 크기 비교 방법')
dot.node('01-09-03-02', '구체물이나 그림을 활용한 크기 비교')

dot.node('01-09-04', '소수의 곱셈과 나눗셈')
dot.node('01-09-04-01', '소수 곱셈 계산 원리 탐구')
dot.node('01-09-04-02', '소수 나눗셈 계산 원리 탐구')


# 소수의 덧셈과 뺄셈
dot.node('01-09-04', '소수의 덧셈과 뺄셈')
dot.node('01-09-04-01', '소수 두 자리 수의 덧셈')
dot.node('01-09-04-02', '소수 두 자리 수의 뺄셈')
dot.node('01-09-04-03', '계산 원리 이해')
dot.node('01-09-04-04', '실생활 문제에서 소수 계산 활용')

# 혼합 계산
dot.node('01-10', '혼합 계산')  # 중분류
dot.node('01-10-01', '혼합 계산의 의미와 순서')
dot.node('01-10-01-01', '혼합 계산의 필요성')
dot.node('01-10-01-02', '사칙연산의 우선순위 이해')

dot.node('01-10-02', '혼합 계산의 사례')
dot.node('01-10-02-01', '두 연산이 섞인 계산')
dot.node('01-10-02-02', '세 연산이 섞인 계산')
dot.node('01-10-02-03', '네 연산이 섞인 계산')

dot.node('01-10-03', '혼합 계산의 활용')
dot.node('01-10-03-01', '실생활 문제 해결에 적용')
dot.node('01-10-03-02', '혼합 계산 결과 검증')

# 약수와 배수
dot.node('01-11', '약수와 배수')  # 중분류
dot.node('01-11-01', '약수와 공약수')
dot.node('01-11-01-01', '약수의 의미 이해')
dot.node('01-11-01-02', '공약수와 최대공약수 구하기')

dot.node('01-11-02', '배수와 공배수')
dot.node('01-11-02-01', '배수의 의미 이해')
dot.node('01-11-02-02', '공배수와 최소공배수 구하기')

# 분수와 소수의 관계
dot.node('01-12', '분수와 소수의 관계')  # 중분류
dot.node('01-12-01', '분수와 소수의 변환')
dot.node('01-12-01-01', '분수를 소수로 변환')
dot.node('01-12-01-02', '소수를 분수로 변환')
dot.node('01-12-02', '분수와 소수의 크기 비교')

# %%
# 대분류와 중분류 연결
dot.edge('01', '01-01')
dot.edge('01', '01-02')
dot.edge('01', '01-03')
dot.edge('01', '01-04')
dot.edge('01', '01-05')
dot.edge('01', '01-07')
dot.edge('01', '01-08')
dot.edge('01', '01-09')
dot.edge('01', '01-10')
dot.edge('01', '01-11')
dot.edge('01', '01-12')

# 중분류와 소분류 연결: 수
dot.edge('01-01', '01-01-01')
dot.edge('01-01', '01-01-02')
dot.edge('01-01', '01-01-03')
dot.edge('01-01', '01-01-04')
dot.edge('01-01', '01-01-05')

# 소분류와 세부 항목 연결: 네 자리 이하의 수
dot.edge('01-01-01', '01-01-01-01')
dot.edge('01-01-01', '01-01-01-02')
dot.edge('01-01-01', '01-01-01-03')
dot.edge('01-01-01', '01-01-01-04')

# 소분류와 세부 항목 연결: 수의 자리값과 위치적 기수법
dot.edge('01-01-02', '01-01-02-01')
dot.edge('01-01-02', '01-01-02-02')
dot.edge('01-01-02', '01-01-02-03')

# 소분류와 세부 항목 연결: 수의 계열과 크기 비교
dot.edge('01-01-03', '01-01-03-01')
dot.edge('01-01-03', '01-01-03-02')
dot.edge('01-01-03', '01-01-03-03')

# 소분류와 세부 항목 연결: 수 감각 기르기
dot.edge('01-01-04', '01-01-04-01')
dot.edge('01-01-04', '01-01-04-02')

# 소분류와 세부 항목 연결: 다섯 자리 이상의 수
dot.edge('01-01-05', '01-01-05-01')
dot.edge('01-01-05', '01-01-05-02')
dot.edge('01-01-05', '01-01-05-03')
dot.edge('01-01-05', '01-01-05-04')
dot.edge('01-01-05', '01-01-05-05')

# 중분류와 소분류 연결: 덧셈
dot.edge('01-02', '01-02-01')
dot.edge('01-02', '01-02-02')
dot.edge('01-02', '01-02-03')
dot.edge('01-02', '01-02-04')
dot.edge('01-02', '01-02-05')

# 소분류와 세부 항목 연결: 덧셈
dot.edge('01-02-01', '01-02-01-01')
dot.edge('01-02-01', '01-02-01-02')
dot.edge('01-02-02', '01-02-02-01')
dot.edge('01-02-02', '01-02-02-02')
dot.edge('01-02-03', '01-02-03-01')
dot.edge('01-02-03', '01-02-03-02')
dot.edge('01-02-04', '01-02-04-01')
dot.edge('01-02-05', '01-02-05-01')
dot.edge('01-02-05', '01-02-05-02')

# 중분류와 소분류 연결: 뺄셈
dot.edge('01-03', '01-03-01')
dot.edge('01-03', '01-03-02')
dot.edge('01-03', '01-03-03')
dot.edge('01-03', '01-03-04')

# 소분류와 세부 항목 연결: 뺄셈
dot.edge('01-03-01', '01-03-01-01')
dot.edge('01-03-01', '01-03-01-02')
dot.edge('01-03-02', '01-03-02-01')
dot.edge('01-03-02', '01-03-02-02')
dot.edge('01-03-03', '01-03-03-01')
dot.edge('01-03-03', '01-03-03-02')
dot.edge('01-03-04', '01-03-04-01')
dot.edge('01-03-04', '01-03-04-02')

# 중분류와 소분류 연결: 곱셈
dot.edge('01-04', '01-04-01')
dot.edge('01-04', '01-04-02')

# 소분류와 세부 항목 연결: 곱셈
dot.edge('01-04-01', '01-04-01-01')
dot.edge('01-04-01', '01-04-01-02')
dot.edge('01-04-02', '01-04-02-01')
dot.edge('01-04-02', '01-04-02-02')
dot.edge('01-04-02', '01-04-02-03')

# 중분류와 소분류 연결: 나눗셈
dot.edge('01-05', '01-05-01')
dot.edge('01-05', '01-05-02')
dot.edge('01-05', '01-05-03')
dot.edge('01-05', '01-05-04')

# 소분류와 세부 항목 연결: 나눗셈
dot.edge('01-05-01', '01-05-01-01')
dot.edge('01-05-01', '01-05-01-02')
dot.edge('01-05-02', '01-05-02-01')
dot.edge('01-05-02', '01-05-02-02')
dot.edge('01-05-03', '01-05-03-01')
dot.edge('01-05-03', '01-05-03-02')
dot.edge('01-05-04', '01-05-04-01')
dot.edge('01-05-04', '01-05-04-02')

# 중분류와 소분류 연결: 자연수의 어림셈
dot.edge('01-07', '01-07-01')
dot.edge('01-07', '01-07-02')
dot.edge('01-07', '01-07-03')
dot.edge('01-07', '01-07-04')

# 소분류와 세부 항목 연결: 어림셈
dot.edge('01-07-01', '01-07-01-01')
dot.edge('01-07-01', '01-07-01-02')
dot.edge('01-07-01', '01-07-01-03')
dot.edge('01-07-02', '01-07-02-01')
dot.edge('01-07-02', '01-07-02-02')
dot.edge('01-07-02', '01-07-02-03')
dot.edge('01-07-03', '01-07-03-01')
dot.edge('01-07-03', '01-07-03-02')
dot.edge('01-07-03', '01-07-03-03')
dot.edge('01-07-04', '01-07-04-01')
dot.edge('01-07-04', '01-07-04-02')
dot.edge('01-07-04', '01-07-04-03')

# 중분류와 소분류 연결: 분수
dot.edge('01-08', '01-08-01')
dot.edge('01-08', '01-08-02')
dot.edge('01-08', '01-08-03')
dot.edge('01-08', '01-08-04')
dot.edge('01-08', '01-08-05')

# 소분류와 세부 항목 연결: 분수
dot.edge('01-08-01', '01-08-01-01')
dot.edge('01-08-01', '01-08-01-02')
dot.edge('01-08-02', '01-08-02-01')
dot.edge('01-08-02', '01-08-02-02')
dot.edge('01-08-03', '01-08-03-01')
dot.edge('01-08-03', '01-08-03-02')
dot.edge('01-08-04', '01-08-04-01')
dot.edge('01-08-04', '01-08-04-02')
dot.edge('01-08-04', '01-08-04-03')
dot.edge('01-08-04', '01-08-04-04')
dot.edge('01-08-05', '01-08-05-01')
dot.edge('01-08-05', '01-08-05-02')

# 중분류와 소분류 연결: 소수
dot.edge('01-09', '01-09-01')
dot.edge('01-09', '01-09-02')
dot.edge('01-09', '01-09-03')
dot.edge('01-09', '01-09-04')

# 소분류와 세부 항목 연결: 소수
dot.edge('01-09-01', '01-09-01-01')
dot.edge('01-09-01', '01-09-01-02')
dot.edge('01-09-02', '01-09-02-01')
dot.edge('01-09-02', '01-09-02-02')
dot.edge('01-09-03', '01-09-03-01')
dot.edge('01-09-03', '01-09-03-02')
dot.edge('01-09-04', '01-09-04-01')
dot.edge('01-09-04', '01-09-04-02')

# 중분류와 소분류 연결: 혼합 계산
dot.edge('01-10', '01-10-01')
dot.edge('01-10', '01-10-02')
dot.edge('01-10', '01-10-03')

# 소분류와 세부 항목 연결: 혼합 계산
dot.edge('01-10-01', '01-10-01-01')
dot.edge('01-10-01', '01-10-01-02')
dot.edge('01-10-02', '01-10-02-01')
dot.edge('01-10-02', '01-10-02-02')
dot.edge('01-10-02', '01-10-02-03')
dot.edge('01-10-03', '01-10-03-01')
dot.edge('01-10-03', '01-10-03-02')

# 중분류와 소분류 연결: 약수와 배수
dot.edge('01-11', '01-11-01')
dot.edge('01-11', '01-11-02')

# 소분류와 세부 항목 연결: 약수와 배수
dot.edge('01-11-01', '01-11-01-01')
dot.edge('01-11-01', '01-11-01-02')
dot.edge('01-11-02', '01-11-02-01')
dot.edge('01-11-02', '01-11-02-02')

# 중분류와 소분류 연결: 분수와 소수의 관계
dot.edge('01-12', '01-12-01')
dot.edge('01-12', '01-12-02')

# 소분류와 세부 항목 연결: 분수와 소수의 관계
dot.edge('01-12-01', '01-12-01-01')
dot.edge('01-12-01', '01-12-01-02')
dot.edge('01-12-02', '01-12-02-01')

# %%
# 글꼴 설정 (맑은 고딕 등 한글 지원 글꼴 지정)
dot.graph_attr.update({
    'fontname': 'Malgun Gothic'  # Windows: 맑은 고딕
})

dot.node_attr.update({
    'fontname': 'Malgun Gothic'
})

# 글꼴 설정 (맑은 고딕 등 한글 지원 글꼴 지정)
dot.edge_attr.update({
    'fontname': 'Malgun Gothic'  # Windows: 맑은 고딕
})

# 그래프 방향 설정 (왼쪽에서 오른쪽으로)
dot.attr(rankdir='LR')

# 다이어그램 생성
dot.render('math_curriculum_diagram', view=True)
# Out:
# 'math_curriculum_diagram.png'

# %%
from graphviz import Digraph

dot = Digraph(comment='수와 연산 분류 체계')

dot.node('01', '수와 연산')  # 대분류

# 중분류와 소분류 추가
def add_nodes(dot, parent, nodes):
    for node_id, label, children in nodes:
        dot.node(node_id, label)
        dot.edge(parent, node_id)
        if children:
            add_nodes(dot, node_id, children)

# 트리 구조 정의
nodes = [
    ('01-01', '수', [
        ('01-01-01', '네 자리 이하의 수', [
            ('01-01-01-01', '수의 필요성 인식', []),
            ('01-01-01-02', '9 이하의 수', []),
            ('01-01-01-03', '99 이하의 수', []),
            ('01-01-01-04', '100 이상의 수', [])
        ]),
        ('01-01-02', '수의 자리값과 위치적 기수법', [
            ('01-01-02-01', '일, 십, 백, 천의 자리', []),
            ('01-01-02-02', '자리값의 합', []),
            ('01-01-02-03', '네 자리 이하의 수 읽기와 쓰기', [])
        ]),
        ('01-01-03', '수의 계열과 크기 비교', [
            ('01-01-03-01', '수의 계열 이해', []),
            ('01-01-03-02', '수의 크기 비교', []),
            ('01-01-03-03', '다양한 방법으로 수 세기', [])
        ]),
        ('01-01-04', '수 감각 기르기', [
            ('01-01-04-01', '하나의 수 분해하기', []),
            ('01-01-04-02', '두 수를 하나로 합성하기', [])
        ]),
        ('01-01-05', '다섯 자리 이상의 수', [
            ('01-01-05-01', '큰 수의 필요성 인식', []),
            ('01-01-05-02', '큰 수의 자리값 이해', []),
            ('01-01-05-03', '큰 수 읽기와 쓰기', []),
            ('01-01-05-04', '수의 계열 이해', []),
            ('01-01-05-05', '수의 크기 비교', [])
        ])
    ]),
    ('01-02', '덧셈', [
        ('01-02-01', '덧셈의 의미', [
            ('01-02-01-01', '덧셈이 이루어지는 실생활 상황과 연결', []),
            ('01-02-01-02', '덧셈의 의미 이해', [])
        ]),
        ('01-02-02', '두 자리 수의 덧셈', [
            ('01-02-02-01', '덧셈의 계산 원리 이해', []),
            ('01-02-02-02', '덧셈의 계산', [])
        ]),
        ('01-02-03', '세 자리 수의 덧셈', [
            ('01-02-03-01', '세 자리 수의 계산', []),
            ('01-02-03-02', '받아올림이 있는 덧셈의 이해', [])
        ]),
        ('01-02-04', '세 수의 덧셈', [
            ('01-02-04-01', '세 수의 계산 이해', [])
        ]),
        ('01-02-05', '□가 사용된 덧셈식', [
            ('01-02-05-01', '실생활 상황을 □가 사용된 덧셈식으로 표현', []),
            ('01-02-05-02', '□값 구하기', [])
        ])
    ]),
    ('01-03', '뺄셈', [
        ('01-03-01', '뺄셈의 의미', [
            ('01-03-01-01', '뺄셈이 이루어지는 실생활 상황과 연결', []),
            ('01-03-01-02', '뺄셈의 의미 이해', [])
        ]),
        ('01-03-02', '두 자리 수의 뺄셈', [
            ('01-03-02-01', '뺄셈의 계산 원리 이해', []),
            ('01-03-02-02', '뺄셈의 계산', [])
        ]),
        ('01-03-03', '세 자리 수의 뺄셈', [
            ('01-03-03-01', '세 자리 수의 계산', []),
            ('01-03-03-02', '받아내림이 있는 뺄셈의 이해', [])
        ]),
        ('01-03-04', '□가 사용된 뺄셈식', [
            ('01-03-04-01', '실생활 상황을 □가 사용된 뺄셈식으로 표현', []),
            ('01-03-04-02', '□값 구하기', [])
        ])
    ]),
    ('01-04', '곱셈', [
        ('01-04-01', '곱셈의 의미', [
            ('01-04-01-01', '곱셈이 이루어지는 실생활 상황 이해', []),
            ('01-04-01-02', '실생활 상황을 곱셈식으로 나타내기', [])
        ]),
        ('01-04-02', '곱셈의 계산', [
            ('01-04-02-01', '두 자리 수 * 한 자리 수', []),
            ('01-04-02-02', '세 자리 수 * 한 자리 수', []),
            ('01-04-02-03', '두 자리 수 * 두 자리 수', [])
        ])
    ]),
    ('01-05', '나눗셈', [
        ('01-05-01', '나눗셈의 의미', [
            ('01-05-01-01', '실생활 속 나눗셈 상황', []),
            ('01-05-01-02', '곱셈과 나눗셈의 관계', [])
        ]),
        ('01-05-02', '나눗셈의 계산', [
            ('01-05-02-01', '나누는 수가 한 자리 수인 나눗셈', []),
            ('01-05-02-02', '나누는 수가 두 자리 수인 나눗셈', [])
        ]),
        ('01-05-03', '몫과 나머지', [
            ('01-05-03-01', '몫과 나머지의 의미', []),
            ('01-05-03-02', '몫과 나머지를 활용한 문제 해결', [])
        ]),
        ('01-05-04', '나눗셈의 활용', [
            ('01-05-04-01', '실생활에서 나눗셈 활용', []),
            ('01-05-04-02', '나눗셈 결과를 검산과 확인', [])
        ])
    ]),
    ('01-07', '자연수의 어림셈', [
        ('01-07-01', '덧셈에서 어림셈', [
            ('01-07-01-01', '덧셈 결과 어림의 필요성', []),
            ('01-07-01-02', '덧셈 어림의 기본 방법', []),
            ('01-07-01-03', '덧셈 어림의 검증', [])
        ]),
        ('01-07-02', '뺄셈에서 어림셈', [
            ('01-07-02-01', '뺄셈 결과 어림의 필요성', []),
            ('01-07-02-02', '뺄셈 어림의 기본 방법', []),
            ('01-07-02-03', '뺄셈 어림의 검증', [])
        ]),
        ('01-07-03', '곱셈에서 어림셈', [
            ('01-07-03-01', '곱셈 결과 어림의 필요성', []),
            ('01-07-03-02', '곱셈 어림의 기본 방법', []),
            ('01-07-03-03', '곱셈 어림의 검증', [])
        ]),
        ('01-07-04', '나눗셈에서 어림셈', [
            ('01-07-04-01', '나눗셈 결과 어림의 필요성', []),
            ('01-07-04-02', '나눗셈 어림의 기본 방법', []),
            ('01-07-04-03', '나눗셈 어림의 검증', [])
        ])
    ]),
    ('01-08', '분수', [
        ('01-08-01', '분수의 개념 이해', [
            ('01-08-01-01', '양의 등분할과 분수의 필요성', []),
            ('01-08-01-02', '분모와 분자의 의미', [])
        ]),
        ('01-08-02', '분수의 종류와 관계', [
            ('01-08-02-01', '단위분수, 진분수, 가분수, 대분수', []),
            ('01-08-02-02', '가분수와 대분수의 변환', [])
        ]),
        ('01-08-03', '분수의 크기 비교', [
            ('01-08-03-01', '분모가 같은 분수의 크기 비교', []),
            ('01-08-03-02', '단위분수끼리의 크기 비교', [])
        ]),
        ('01-08-04', '분수의 덧셈과 뺄셈', [
            ('01-08-04-01', '분모가 같은 분수의 덧셈', []),
            ('01-08-04-02', '분모가 같은 분수의 뺄셈', []),
            ('01-08-04-03', '계산 원리 이해', []),
            ('01-08-04-04', '실생활 문제에서 분수 계산 활용', [])
        ]),
        ('01-08-05', '분수의 곱셈과 나눗셈', [
            ('01-08-05-01', '분수의 곱셈의 계산 원리 탐구', []),
            ('01-08-05-02', '분수의 나눗셈의 계산 원리 탐구', [])
        ])
    ]),
    ('01-09', '소수', [
        ('01-09-01', '소수의 개념 이해', [
            ('01-09-01-01', '분모가 10인 진분수와 소수의 관계', []),
            ('01-09-01-02', '소수 한 자리 수 읽기와 쓰기', [])
        ]),
        ('01-09-02', '소수의 자릿값과 계산', [
            ('01-09-02-01', '소수 두 자리 수와 세 자리 수의 자릿값 이해', []),
            ('01-09-02-02', '소수의 덧셈과 뺄셈 원리', [])
        ]),
        ('01-09-03', '소수의 크기 비교', [
            ('01-09-03-01', '소수의 크기 비교 방법', []),
            ('01-09-03-02', '구체물이나 그림을 활용한 크기 비교', [])
        ]),
        ('01-09-04', '소수의 덧셈과 뺄셈', [
            ('01-09-04-01', '소수 두 자리 수의 덧셈', []),
            ('01-09-04-02', '소수 두 자리 수의 뺄셈', []),
            ('01-09-04-03', '계산 원리 이해', []),
            ('01-09-04-04', '실생활 문제에서 소수 계산 활용', [])
        ]),
        ('01-09-05', '소수의 곱셈과 나눗셈', [
            ('01-09-05-01', '소수 곱셈 계산 원리 탐구', []),
            ('01-09-05-02', '소수 나눗셈 계산 원리 탐구', [])
        ])
    ]),
    ('01-10', '혼합 계산', [
        ('01-10-01', '혼합 계산의 의미와 순서', [
            ('01-10-01-01', '혼합 계산의 필요성', []),
            ('01-10-01-02', '사칙연산의 우선순위 이해', [])
        ]),
        ('01-10-02', '혼합 계산의 사례', [
            ('01-10-02-01', '두 연산이 섞인 계산', []),
            ('01-10-02-02', '세 연산이 섞인 계산', []),
            ('01-10-02-03', '네 연산이 섞인 계산', [])
        ]),
        ('01-10-03', '혼합 계산의 활용', [
            ('01-10-03-01', '실생활 문제 해결에 적용', []),
            ('01-10-03-02', '혼합 계산 결과 검증', [])
        ])
    ]),
    ('01-11', '약수와 배수', [
        ('01-11-01', '약수와 공약수', [
            ('01-11-01-01', '약수의 의미 이해', []),
            ('01-11-01-02', '공약수와 최대공약수 구하기', [])
        ]),
        ('01-11-02', '배수와 공배수', [
            ('01-11-02-01', '배수의 의미 이해', []),
            ('01-11-02-02', '공배수와 최소공배수 구하기', [])
        ])
    ]),
    ('01-12', '분수와 소수의 관계', [
        ('01-12-01', '분수와 소수의 변환', [
            ('01-12-01-01', '분수를 소수로 변환', []),
            ('01-12-01-02', '소수를 분수로 변환', [])
        ]),
        ('01-12-02', '분수와 소수의 크기 비교', [])
    ])
]

# 트리 구조 추가
add_nodes(dot, '01', nodes)

dot.attr(rankdir='LR')

# 그래프 시각화
# 주의: 실제로 저장하거나 파일로 출력하려면 render() 메서드를 사용해야 합니다.
dot.render('math_classification_graph', format='png', view=True)  # PNG 파일로 저장하고 뷰어로 열기
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.956561 to fit
# 'math_classification_graph.png'
